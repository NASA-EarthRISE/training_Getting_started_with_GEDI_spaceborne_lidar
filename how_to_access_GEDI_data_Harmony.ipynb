# %% [markdown]
# <a href="https://colab.research.google.com/github/SERVIR/GEDI_Earthhub_ARSET_Training/blob/main/how_to_access_GEDI_data_Harmony.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Accessing GEDI data using NASA Harmony API

# %% [markdown]
# Harmony provides access to services that can transform data from NASA's [Earth Observing Systems Data and Information System (EOSDIS)](https://www.earthdata.nasa.gov/eosdis) Distributed Active Archive Centers (DAAC). [`harmony-py`](https://github.com/nasa/harmony-py) Python package is the recommended way of interacting with Harmony service. This notebook shows how to query and access customized [NASA's LP DAAC](https://lpdaac.usgs.gov/)  GEDI data outputs using [NASA's Harmony Services](https://harmony.earthdata.nasa.gov/).

# %% [markdown]
# ## Authenticate

# %%
# !pip install geoviews earthaccess harmony-py hvplot
# Out:
# Requirement already satisfied: geoviews in /usr/local/lib/python3.11/dist-packages (1.14.0)
# Requirement already satisfied: earthaccess in /usr/local/lib/python3.11/dist-packages (0.14.0)
# Requirement already satisfied: harmony-py in /usr/local/lib/python3.11/dist-packages (1.2.0)
# Requirement already satisfied: hvplot in /usr/local/lib/python3.11/dist-packages (0.11.3)
# Requirement already satisfied: bokeh>=3.6.0 in /usr/local/lib/python3.11/dist-packages (from geoviews) (3.7.3)
# Requirement already satisfied: cartopy>=0.18.0 in /usr/local/lib/python3.11/dist-packages (from geoviews) (0.24.1)
# Requirement already satisfied: holoviews>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from geoviews) (1.20.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from geoviews) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from geoviews) (24.2)
# Requirement already satisfied: panel>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from geoviews) (1.7.0)
# Requirement already satisfied: param<3.0,>=1.9.3 in /usr/local/lib/python3.11/dist-packages (from geoviews) (2.2.0)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.11/dist-packages (from geoviews) (3.7.1)
# Requirement already satisfied: shapely in /usr/local/lib/python3.11/dist-packages (from geoviews) (2.0.7)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.11/dist-packages (from geoviews) (2025.4.0)
# Requirement already satisfied: fsspec>=2022.11 in /usr/local/lib/python3.11/dist-packages (from earthaccess) (2025.5.1)
# Requirement already satisfied: importlib-resources>=6.3.2 in /usr/local/lib/python3.11/dist-packages (from earthaccess) (6.5.2)
# Requirement already satisfied: multimethod>=1.8 in /usr/local/lib/python3.11/dist-packages (from earthaccess) (2.0)
# Requirement already satisfied: pqdm>=0.1 in /usr/local/lib/python3.11/dist-packages (from earthaccess) (0.2.0)
# Requirement already satisfied: python-cmr>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from earthaccess) (0.13.0)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.11/dist-packages (from earthaccess) (2.32.3)
# Requirement already satisfied: s3fs>=2022.11 in /usr/local/lib/python3.11/dist-packages (from earthaccess) (2025.5.1)
# Requirement already satisfied: tinynetrc>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from earthaccess) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from earthaccess) (4.13.2)
# Requirement already satisfied: python-dateutil~=2.9 in /usr/local/lib/python3.11/dist-packages (from harmony-py) (2.9.0.post0)
# Requirement already satisfied: python-dotenv~=0.20.0 in /usr/local/lib/python3.11/dist-packages (from harmony-py) (0.20.0)
# Requirement already satisfied: progressbar2~=4.2.0 in /usr/local/lib/python3.11/dist-packages (from harmony-py) (4.2.0)
# Requirement already satisfied: sphinxcontrib-napoleon~=0.7 in /usr/local/lib/python3.11/dist-packages (from harmony-py) (0.7)
# Requirement already satisfied: curlify~=2.2.1 in /usr/local/lib/python3.11/dist-packages (from harmony-py) (2.2.1)
# Requirement already satisfied: colorcet>=2 in /usr/local/lib/python3.11/dist-packages (from hvplot) (3.1.0)
# Requirement already satisfied: pandas>=1.3 in /usr/local/lib/python3.11/dist-packages (from hvplot) (2.2.2)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.11/dist-packages (from bokeh>=3.6.0->geoviews) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in /usr/local/lib/python3.11/dist-packages (from bokeh>=3.6.0->geoviews) (1.3.2)
# Requirement already satisfied: narwhals>=1.13 in /usr/local/lib/python3.11/dist-packages (from bokeh>=3.6.0->geoviews) (1.40.0)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from bokeh>=3.6.0->geoviews) (11.2.1)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.11/dist-packages (from bokeh>=3.6.0->geoviews) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.11/dist-packages (from bokeh>=3.6.0->geoviews) (6.4.2)
# Requirement already satisfied: matplotlib>=3.6 in /usr/local/lib/python3.11/dist-packages (from cartopy>=0.18.0->geoviews) (3.10.0)
# Requirement already satisfied: pyshp>=2.3 in /usr/local/lib/python3.11/dist-packages (from cartopy>=0.18.0->geoviews) (2.3.1)
# Requirement already satisfied: pyviz-comms>=2.1 in /usr/local/lib/python3.11/dist-packages (from holoviews>=1.16.0->geoviews) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3->hvplot) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3->hvplot) (2025.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from panel>=1.0.0->geoviews) (6.2.0)
# Requirement already satisfied: linkify-it-py in /usr/local/lib/python3.11/dist-packages (from panel>=1.0.0->geoviews) (2.0.3)
# Requirement already satisfied: markdown in /usr/local/lib/python3.11/dist-packages (from panel>=1.0.0->geoviews) (3.8)
# Requirement already satisfied: markdown-it-py in /usr/local/lib/python3.11/dist-packages (from panel>=1.0.0->geoviews) (3.0.0)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.11/dist-packages (from panel>=1.0.0->geoviews) (0.4.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from panel>=1.0.0->geoviews) (4.67.1)
# Requirement already satisfied: bounded-pool-executor in /usr/local/lib/python3.11/dist-packages (from pqdm>=0.1->earthaccess) (0.0.3)
# Requirement already satisfied: python-utils>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from progressbar2~=4.2.0->harmony-py) (3.9.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from pyproj->geoviews) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil~=2.9->harmony-py) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26->earthaccess) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26->earthaccess) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26->earthaccess) (2.4.0)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /usr/local/lib/python3.11/dist-packages (from s3fs>=2022.11->earthaccess) (2.22.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from s3fs>=2022.11->earthaccess) (3.11.15)
# Requirement already satisfied: pockets>=0.3 in /usr/local/lib/python3.11/dist-packages (from sphinxcontrib-napoleon~=0.7->harmony-py) (0.9.1)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2022.11->earthaccess) (0.12.0)
# Requirement already satisfied: botocore<1.37.4,>=1.37.2 in /usr/local/lib/python3.11/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2022.11->earthaccess) (1.37.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2022.11->earthaccess) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2022.11->earthaccess) (6.4.4)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /usr/local/lib/python3.11/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2022.11->earthaccess) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2022.11->earthaccess) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2022.11->earthaccess) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2022.11->earthaccess) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2022.11->earthaccess) (1.6.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2022.11->earthaccess) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2022.11->earthaccess) (1.20.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=2.9->bokeh>=3.6.0->geoviews) (3.0.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->cartopy>=0.18.0->geoviews) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->cartopy>=0.18.0->geoviews) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->cartopy>=0.18.0->geoviews) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->cartopy>=0.18.0->geoviews) (3.2.3)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach->panel>=1.0.0->geoviews) (0.5.1)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.11/dist-packages (from linkify-it-py->panel>=1.0.0->geoviews) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py->panel>=1.0.0->geoviews) (0.1.2)

# %%
from harmony import BBox, Client, Collection, Request, CapabilitiesRequest
from datetime import datetime
import json
import earthaccess
import geopandas as gp
import os
from IPython.display import JSON
import h5py
import pandas as pd
from shapely.geometry import Point
import hvplot.pandas

os.chdir('../../')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='1357253a-438e-4149-ae6f-caec9fff0c58'>
#   <div id="e0e51fea-1ed3-4265-bfd1-10f7cdc8fd07" data-root-id="1357253a-438e-4149-ae6f-caec9fff0c58" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"5e4ae9f1-9bd2-45f8-9e16-72e270b377a9":{"version":"3.7.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"1357253a-438e-4149-ae6f-caec9fff0c58"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"f8cb68fe-1ca9-45ad-9056-b90b05f0c724","attributes":{"plot_id":"1357253a-438e-4149-ae6f-caec9fff0c58","comm_id":"b596ae4b2fad43fd8f61f3c3881a5c81","client_comm_id":"b129afdbcb2b4029a60e69fcf2c84e9b"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1" ...
#   var render_items = [{"docid":"5e4ae9f1-9bd2-45f8-9e16-72e270b377a9","roots":{"1357253a-438e-4149-ae6f-caec9fff0c58":"e0e51fea-1ed3-4265-bfd1-10f7cdc8fd07"},"root_ids":["1357253a-438e-4149-ae6f-caec9fff0c58"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='2506a52f-a125-4175-b14b-737b332e538c'>
#   <div id="d3f65385-b9dd-4825-b028-3b318122805b" data-root-id="2506a52f-a125-4175-b14b-737b332e538c" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"86d295f0-b4cf-4f38-80a4-a75ddabfc3d8":{"version":"3.7.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"2506a52f-a125-4175-b14b-737b332e538c"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"a07a331d-4601-41ec-ac77-4d2432292eab","attributes":{"plot_id":"2506a52f-a125-4175-b14b-737b332e538c","comm_id":"86fb51afc6ae4204b5a43d88ef8f143b","client_comm_id":"8ebc3a8086504d478d7a38745d5ecfb7"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1" ...
#   var render_items = [{"docid":"86d295f0-b4cf-4f38-80a4-a75ddabfc3d8","roots":{"2506a52f-a125-4175-b14b-737b332e538c":"d3f65385-b9dd-4825-b028-3b318122805b"},"root_ids":["2506a52f-a125-4175-b14b-737b332e538c"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %% [markdown]
# `earthaccess.login()` is used here to access NASA Earthdata Login (EDL) credentials stored in a .netrc file and allows users to type their credentials and persist them to a .netrc file if one does not exist.

# %%
auth = earthaccess.login(persist=True)
# auth.token
# Out:
# Enter your Earthdata Login username: tjm0042
# Enter your Earthdata password: ··········

# %% [markdown]
# To access data through Harmony service, we need to create a Harmony Client object using either your EDL token or your Earthdata Login credentials. Below, `username` and `password` are directly provided to `Client` function. See [here](https://github.com/nasa/harmony-py/blob/main/examples/intro_tutorial.ipynb) for other options you can create Harmony Client object.

# %%
harmony_client = Client(auth=(auth.username, auth.password))

# %% [markdown]
# ## Get the GEDI Collections Harmoney Capabilities

# %% [markdown]
# Let us start by submitting a capabilities request to see the transformation supported in Harmony API using the GEDI product short names ('GEDI02_A', 'GEDI02_B', 'GEDI01_B'). Besides the `conceptId` and available variables, You can view the supported transformation services. Supported transformation services and variables (such as variable subsetting, bounding box subsetting, shapefile subsetting, concatenation and reprojection, etc.) have `True` value. Based on the returned capabilities information for GEDI , we can submit a variable subsetting request, bounding box/shapefile subsetting, and temporal subsetting.

# %%
capabilities = harmony_client.submit(CapabilitiesRequest(short_name='GEDI02_B'))
print(json.dumps(capabilities, indent=2))
# Out:
# Streaming output truncated to the last 5000 lines.
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_flag_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648441-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_gamma_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648444-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_gamma_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648446-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_gamma_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648448-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_gamma_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648451-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_gamma_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648453-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_gamma_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648455-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_gamma_error_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648457-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_gamma_error_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648459-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_gamma_error_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648461-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_gamma_error_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648463-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_gamma_error_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648465-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_gamma_error_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648467-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_niter_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648469-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_niter_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648471-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_niter_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648475-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_niter_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648477-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_niter_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648479-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_niter_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648481-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_sigma_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648483-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_sigma_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648486-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_sigma_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648490-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_sigma_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648493-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_sigma_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648495-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_sigma_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648498-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_sigma_error_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648501-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_sigma_error_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648506-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_sigma_error_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648510-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_sigma_error_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648514-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_sigma_error_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648516-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_sigma_error_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648518-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_error_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648520-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_error_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648522-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_error_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648524-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_error_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648526-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_error_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648528-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_error_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648530-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rv_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648532-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rv_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648535-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rv_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648537-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rv_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648539-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rv_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648541-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rv_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648543-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rx_energy_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648545-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rx_energy_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648547-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rx_energy_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648550-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rx_energy_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648552-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rx_energy_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648554-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rx_energy_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648556-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/shot_number",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648558-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_range_highestreturn",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648156-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_sample_count",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648159-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_sample_start_index",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648162-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/selected_l2a_algorithm",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648165-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/selected_mode",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648171-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/selected_mode_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648174-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/selected_rg_algorithm",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648176-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/sensitivity",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648178-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/shot_number",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648180-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/stale_return_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648182-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/surface_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648185-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/algorithmrun_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648560-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/ancillary/dz",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648929-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/ancillary/l2a_alg_count",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648932-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/ancillary/maxheight_cuttoff",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648935-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/ancillary/rg_eg_constraint_center_buffer",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648937-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/ancillary/rg_eg_mpfit_max_func_evals",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648939-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/ancillary/rg_eg_mpfit_maxiters",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648941-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/ancillary/rg_eg_mpfit_tolerance",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648943-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/ancillary/signal_search_buff",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648945-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/ancillary/tx_noise_stddev_multiplier",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648947-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/beam",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648585-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/channel",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648626-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/cover",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648667-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/cover_z",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648710-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/delta_time",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648755-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/fhd_normal",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648797-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/geolocation/degrade_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648952-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/geolocation/delta_time",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648959-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/geolocation/digital_elevation_model",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648963-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/geolocation/elev_highestreturn",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648970-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/geolocation/elev_lowestmode",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648976-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/geolocation/elevation_bin0",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648985-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/geolocation/elevation_bin0_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648992-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/geolocation/elevation_lastbin",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649000-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/geolocation/elevation_lastbin_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649010-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/geolocation/height_bin0",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649017-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/geolocation/height_lastbin",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649024-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/geolocation/lat_highestreturn",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649029-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/geolocation/lat_lowestmode",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649036-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/geolocation/latitude_bin0",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649041-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/geolocation/latitude_bin0_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649044-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/geolocation/latitude_lastbin",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649051-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/geolocation/latitude_lastbin_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649056-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/geolocation/local_beam_azimuth",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649062-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/geolocation/local_beam_elevation",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649068-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/geolocation/lon_highestreturn",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649075-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/geolocation/lon_lowestmode",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649082-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/geolocation/longitude_bin0",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649087-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/geolocation/longitude_bin0_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649091-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/geolocation/longitude_lastbin",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649095-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/geolocation/longitude_lastbin_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649102-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/geolocation/shot_number",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649109-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/geolocation/solar_azimuth",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649114-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/geolocation/solar_elevation",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649119-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/l2a_quality_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648836-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/l2b_quality_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648859-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/land_cover_data/landsat_treecover",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649124-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/land_cover_data/landsat_water_persistence",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649129-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/land_cover_data/leaf_off_doy",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649138-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/land_cover_data/leaf_off_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649142-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/land_cover_data/leaf_on_cycle",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649148-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/land_cover_data/leaf_on_doy",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649152-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/land_cover_data/modis_nonvegetated",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649155-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/land_cover_data/modis_nonvegetated_sd",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649157-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/land_cover_data/modis_treecover",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649160-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/land_cover_data/modis_treecover_sd",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649163-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/land_cover_data/pft_class",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649165-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/land_cover_data/region_class",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649167-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/land_cover_data/urban_focal_window_size",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649170-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/land_cover_data/urban_proportion",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649173-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/master_frac",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648861-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/master_int",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648863-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/num_detectedmodes",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648865-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/omega",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648867-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/pai",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648869-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/pai_z",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648871-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/pavd_z",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648873-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/pgap_theta",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648875-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/pgap_theta_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648877-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/pgap_theta_z",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648879-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rg",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648881-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rh100",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648883-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rhog",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648885-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rhog_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648887-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rhov",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648889-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rhov_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648891-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rossg",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648896-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rv",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648901-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/algorithmrun_flag_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649175-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/algorithmrun_flag_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649177-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/algorithmrun_flag_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649179-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/algorithmrun_flag_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649181-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/algorithmrun_flag_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649183-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/algorithmrun_flag_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649185-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/pgap_theta_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649189-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/pgap_theta_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649191-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/pgap_theta_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649194-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/pgap_theta_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649196-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/pgap_theta_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649198-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/pgap_theta_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649200-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/pgap_theta_error_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649202-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/pgap_theta_error_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649204-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/pgap_theta_error_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649207-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/pgap_theta_error_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649211-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/pgap_theta_error_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649217-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/pgap_theta_error_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649222-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649226-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649229-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649234-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649237-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649240-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649246-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_amplitude_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649257-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_amplitude_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649262-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_amplitude_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649264-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_amplitude_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649266-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_amplitude_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649268-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_amplitude_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649270-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_amplitude_error_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649272-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_amplitude_error_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649274-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_amplitude_error_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649276-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_amplitude_error_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649278-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_amplitude_error_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649280-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_amplitude_error_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649282-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_center_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649284-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_center_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649286-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_center_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649288-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_center_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649290-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_center_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649292-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_center_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649294-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_center_error_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649296-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_center_error_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649298-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_center_error_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649301-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_center_error_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649303-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_center_error_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649306-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_center_error_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649308-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_chisq_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649310-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_chisq_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649314-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_chisq_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649316-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_chisq_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649318-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_chisq_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649320-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_chisq_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649322-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_flag_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649325-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_flag_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649327-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_flag_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649329-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_flag_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649331-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_flag_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649334-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_flag_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649337-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_gamma_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649339-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_gamma_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649341-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_gamma_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649343-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_gamma_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649345-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_gamma_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649347-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_gamma_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649349-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_gamma_error_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649351-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_gamma_error_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649354-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_gamma_error_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649356-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_gamma_error_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649360-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_gamma_error_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649362-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_gamma_error_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649365-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_niter_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649367-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_niter_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649370-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_niter_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649373-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_niter_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649375-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_niter_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649377-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_niter_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649379-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_sigma_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649382-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_sigma_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649386-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_sigma_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649388-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_sigma_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649390-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_sigma_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649392-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_sigma_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649395-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_sigma_error_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649401-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_sigma_error_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649408-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_sigma_error_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649413-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_sigma_error_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649421-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_sigma_error_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649423-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_eg_sigma_error_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649428-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_error_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649434-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_error_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649443-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_error_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649448-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_error_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649454-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_error_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649459-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rg_error_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649463-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rv_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649467-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rv_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649471-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rv_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649473-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rv_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649475-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rv_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649479-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rv_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649481-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rx_energy_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649483-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rx_energy_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649485-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rx_energy_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649487-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rx_energy_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649489-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rx_energy_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649492-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/rx_energy_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649494-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_processing/shot_number",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649496-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_range_highestreturn",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648903-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_sample_count",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648905-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/rx_sample_start_index",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648907-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/selected_l2a_algorithm",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648909-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/selected_mode",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648911-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/selected_mode_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648913-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/selected_rg_algorithm",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648915-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/sensitivity",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648917-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/shot_number",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648920-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/stale_return_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648922-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0010/surface_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648926-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/algorithmrun_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649498-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/ancillary/dz",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649617-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/ancillary/l2a_alg_count",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649620-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/ancillary/maxheight_cuttoff",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649623-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/ancillary/rg_eg_constraint_center_buffer",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649626-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/ancillary/rg_eg_mpfit_max_func_evals",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649629-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/ancillary/rg_eg_mpfit_maxiters",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649632-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/ancillary/rg_eg_mpfit_tolerance",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649635-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/ancillary/signal_search_buff",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649638-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/ancillary/tx_noise_stddev_multiplier",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649641-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/beam",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649501-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/channel",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649503-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/cover",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649505-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/cover_z",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649508-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/delta_time",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649510-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/fhd_normal",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649512-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/geolocation/degrade_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649645-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/geolocation/delta_time",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649651-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/geolocation/digital_elevation_model",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649654-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/geolocation/elev_highestreturn",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649658-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/geolocation/elev_lowestmode",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649660-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/geolocation/elevation_bin0",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649662-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/geolocation/elevation_bin0_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649664-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/geolocation/elevation_lastbin",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649666-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/geolocation/elevation_lastbin_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649668-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/geolocation/height_bin0",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649670-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/geolocation/height_lastbin",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649672-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/geolocation/lat_highestreturn",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649674-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/geolocation/lat_lowestmode",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649676-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/geolocation/latitude_bin0",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649678-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/geolocation/latitude_bin0_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649680-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/geolocation/latitude_lastbin",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649684-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/geolocation/latitude_lastbin_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649686-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/geolocation/local_beam_azimuth",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649688-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/geolocation/local_beam_elevation",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649690-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/geolocation/lon_highestreturn",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649693-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/geolocation/lon_lowestmode",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649695-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/geolocation/longitude_bin0",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649698-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/geolocation/longitude_bin0_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649700-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/geolocation/longitude_lastbin",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649703-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/geolocation/longitude_lastbin_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649706-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/geolocation/shot_number",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649708-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/geolocation/solar_azimuth",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649710-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/geolocation/solar_elevation",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649712-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/l2a_quality_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649515-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/l2b_quality_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649517-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/land_cover_data/landsat_treecover",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649714-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/land_cover_data/landsat_water_persistence",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649716-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/land_cover_data/leaf_off_doy",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649718-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/land_cover_data/leaf_off_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649720-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/land_cover_data/leaf_on_cycle",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649722-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/land_cover_data/leaf_on_doy",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649724-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/land_cover_data/modis_nonvegetated",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649727-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/land_cover_data/modis_nonvegetated_sd",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649729-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/land_cover_data/modis_treecover",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649731-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/land_cover_data/modis_treecover_sd",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649733-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/land_cover_data/pft_class",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649735-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/land_cover_data/region_class",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649738-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/land_cover_data/urban_focal_window_size",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649740-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/land_cover_data/urban_proportion",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649744-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0011/master_frac",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837649519-LPCLOUD"
# ...
#     },
#     {
#       "name": "/BEAM1011/rx_processing/pgap_theta_error_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653182-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/pgap_theta_error_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653184-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/pgap_theta_error_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653187-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653189-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653191-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653193-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653195-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653197-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653200-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_amplitude_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653202-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_amplitude_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653204-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_amplitude_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653206-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_amplitude_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653208-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_amplitude_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653210-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_amplitude_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653212-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_amplitude_error_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653214-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_amplitude_error_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653216-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_amplitude_error_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653218-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_amplitude_error_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653220-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_amplitude_error_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653222-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_amplitude_error_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653224-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_center_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653226-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_center_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653229-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_center_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653232-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_center_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653235-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_center_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653237-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_center_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653240-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_center_error_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653242-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_center_error_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653244-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_center_error_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653246-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_center_error_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653248-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_center_error_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653250-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_center_error_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653252-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_chisq_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653254-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_chisq_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653256-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_chisq_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653258-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_chisq_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653260-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_chisq_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653262-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_chisq_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653264-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_flag_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653266-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_flag_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653268-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_flag_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653273-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_flag_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653275-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_flag_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653277-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_flag_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653279-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_gamma_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653281-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_gamma_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653283-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_gamma_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653285-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_gamma_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653287-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_gamma_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653289-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_gamma_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653291-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_gamma_error_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653293-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_gamma_error_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653295-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_gamma_error_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653297-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_gamma_error_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653299-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_gamma_error_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653301-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_gamma_error_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653304-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_niter_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653306-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_niter_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653308-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_niter_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653310-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_niter_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653312-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_niter_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653318-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_niter_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653327-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_sigma_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653341-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_sigma_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653356-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_sigma_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653370-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_sigma_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653375-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_sigma_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653381-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_sigma_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653383-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_sigma_error_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653385-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_sigma_error_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653387-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_sigma_error_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653389-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_sigma_error_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653391-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_sigma_error_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653393-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_sigma_error_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653395-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_error_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653397-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_error_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653399-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_error_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653401-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_error_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653403-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_error_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653405-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_error_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653407-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rv_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653409-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rv_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653411-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rv_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653413-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rv_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653416-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rv_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653418-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rv_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653420-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rx_energy_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653423-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rx_energy_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653425-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rx_energy_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653428-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rx_energy_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653431-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rx_energy_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653433-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rx_energy_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653435-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/shot_number",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653437-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_range_highestreturn",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837652968-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_sample_count",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837652970-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_sample_start_index",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837652972-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/selected_l2a_algorithm",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837652974-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/selected_mode",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837652976-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/selected_mode_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837652978-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/selected_rg_algorithm",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837652980-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/sensitivity",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837652982-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/shot_number",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837652985-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/stale_return_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837652988-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/surface_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837652990-LPCLOUD"
#     }
#   ],
#   "capabilitiesVersion": "2"
# }

# %% [markdown]
# ## Create a Harmony Request
#
# There are several parameters that can be used for the Harmony request. See [the documentation](https://harmony-py.readthedocs.io/en/latest/) and [the introductory Harmony tutorial ](https://github.com/nasa/harmony-py/blob/main/examples/intro_tutorial.ipynb) for more details.

# %% [markdown]
# ### GEDI Collection Concept ID
#
# `collection` is a Required parameter. The concept ID, which is the NASA EOSDIS collection ID provided in the Common Metadata Repository (CMR) metadata **OR** Product short name (e.g. 'C2142776747-LPCLOUD') can be provided to search for collections.
#
# Below, `concept_id` is saved to a variable.

# %%
print(capabilities['shortName'], ',', capabilities['conceptId'])

concept_id = capabilities['conceptId']
# Out:
# GEDI02_B , C2142776747-LPCLOUD
# GEDI02_B , C2142776747-LPCLOUD

# %% [markdown]
# ### GEDI Variable Subset

# %% [markdown]
# To learn more about the available layers, you can view the GEDI Dictionaries provided in [GEDI products' DOI Landing pages](https://lpdaac.usgs.gov/product_search/?query=gedi&status=Operational&view=cards&sort=title). The available GEDI datasets are also saved into a JSON file (`GEDI_Datasets.json`) stored in `data` folder and is used to view the available datasets here.

# %%
field = {"GEDI_L1B": ["geolocation/altitude_instrument", "geolocation/local_beam_elevation", "tx_sample_start_index", "nsemean_odd", "ancillary/master_time_epoch", "noise_stddev_corrected", "tx_pulseflag", "geolocation/longitude_bin0_error", "selection_stretchers_x", "nsemean_even", "geolocation/latitude_instrument", "geolocation/digital_elevation_model", "geolocation/longitude_instrument_error", "geolocation/longitude_lastbin_error", "tx_egsigma", "geolocation/neutat_delay_total_bin0", "rx_energy", "master_frac", "rx_sample_count", "rxwaveform", "tx_gloc", "ancillary/mean_samples", "geolocation/longitude_instrument", "tx_eggamma_error", "rx_offset", "tx_egbias_error", "geolocation/bounce_time_offset_lastbin", "all_samples_sum", "geophys_corr/tide_load", "geolocation/solar_azimuth", "geolocation/mean_sea_surface", "geolocation/neutat_delay_total_lastbin", "th_left_used", "rx_sample_start_index", "geophys_corr/tide_ocean", "geophys_corr/tide_ocean_pole", "tx_eggamma", "geophys_corr/tide_pole", "tx_sample_count", "geolocation/surface_type", "geolocation/neutat_delay_derivative_bin0", "geolocation/digital_elevation_model_srtm", "shot_number", "txwaveform", "geolocation/latitude_bin0_error", "geolocation/altitude_instrument_error", "channel", "geolocation/longitude_lastbin", "geolocation/latitude_lastbin", "geolocation/elevation_bin0_error", "geolocation/shot_number", "geolocation/solar_elevation", "geolocation/local_beam_elevation_error", "tx_egamplitude", "geolocation/latitude_bin0", "geolocation/elevation_lastbin_error", "ancillary/smoothing_width", "geolocation/latitude_instrument_error", "tx_egbias", "geolocation/bounce_time_offset_bin0_error", "geolocation/bounce_time_offset_bin0", "rx_open", "beam", "geolocation/local_beam_azimuth", "tx_egflag", "tx_egsigma_error", "geolocation/bounce_time_offset_lastbin_error", "tx_gloc_error", "geophys_corr/geoid", "selection_stretchers_y", "geolocation/latitude_lastbin_error", "master_int", "geolocation/range_bias_correction", "geolocation/elevation_lastbin", "geolocation/longitude_bin0", "stale_return_flag", "geolocation/delta_time", "noise_mean_corrected", "geolocation/local_beam_azimuth_error", "geophys_corr/dynamic_atmosphere_correction", "geophys_corr/delta_time", "tx_egamplitude_error", "geolocation/elevation_bin0", "geolocation/neutat_delay_derivative_lastbin", "geolocation/degrade", "geophys_corr/tide_earth"], "GEDI_L2A": ["rx_processing_a4/ancillary/rx_subbin_resolution", "rx_processing_a6/ancillary/rx_use_fixed_thresholds", "rx_processing_a1/rx_iwaveamps", "rx_processing_a1/selected_mode_flag", "rx_processing_a2/sd_sm", "geolocation/elev_highestreturn_a2", "rx_processing_a2/zcross0", "geolocation/rh_a6", "rx_processing_a2/ancillary/preprocessor_threshold", "rx_processing_a4/ancillary/rx_max_mode_count", "geolocation/elevs_allmodes_a3", "rx_processing_a1/ancillary/rx_smoothing_width_zcross", "rx_processing_a6/sd_sm", "rx_processing_a3/rx_cumulative", "geolocation/quality_flag_a6", "lat_highestreturn", "rx_1gaussfit/ancillary/rx_constraint_gloc_upper", "rx_assess/ancillary/rx_pulsethresh", "rx_processing_a3/selected_mode", "rx_processing_a5/ancillary/enable_select_mode", "geolocation/elev_highestreturn_a1", "rx_processing_a1/toploc", "rx_1gaussfit/ancillary/rx_estimate_bias", "rx_processing_a1/search_start", "rx_processing_a6/ancillary/rx_subbin_resolution", "rx_processing_a6/zcross_localenergy", "geolocation/energy_lowestmode_a6", "master_frac", "rx_processing_a4/ancillary/ampval_limit3", "rx_processing_a6/selected_mode", "geolocation/lat_highestreturn_a4", "rx_processing_a1/ancillary/botlocdist_limit2", "rx_processing_a3/min_detection_energy", "rx_processing_a6/peak", "rx_processing_a5/rx_modelocalslope", "rx_processing_a6/ancillary/cumulative_energy_thresh", "geolocation/lon_lowestmode_a6", "rx_processing_a6/ancillary/pulse_sep_thresh", "rx_processing_a5/lastmodeenergy", "rx_1gaussfit/ancillary/rx_constraint_gamplitude_upper", "geolocation/elevs_allmodes_a5", "rx_assess/rx_energy", "rx_processing_a6/rx_cumulative", "delta_time", "rx_processing_a2/rx_modelocs", "rx_processing_a6/ancillary/rx_searchsize", "elev_lowestmode", "rx_processing_a3/selected_mode_flag", "rx_processing_a5/pk_sm", "rx_processing_a2/ancillary/rx_subbin_resolution", "rx_processing_a5/ancillary/botlocdist_limit2", "geolocation/lats_allmodes_a3", "geolocation/lat_highestreturn_a5", "geolocation/lon_lowestreturn_a6", "rx_processing_a1/energy_sm", "rx_processing_a5/stddev", "rx_processing_a2/ancillary/rx_use_fixed_thresholds", "geolocation/lon_lowestmode_a4", "rx_processing_a3/ancillary/rx_back_threshold", "geolocation/num_detectedmodes_a1", "rx_processing_a3/ancillary/botlocdist_limit3", "rx_processing_a1/ancillary/rx_searchsize", "rx_processing_a2/toploc_miss", "geolocation/lat_highestreturn_a6", "rx_processing_a3/ancillary/botlocdist_limit1", "rx_processing_a5/rx_modelocs", "rx_processing_a6/ancillary/botlocdist_limit3", "geolocation/lon_lowestreturn_a1", "geolocation/rh_a1", "land_cover_data/modis_nonvegetated_sd", "rx_processing_a1/rx_modeenergytobotloc", "rx_processing_a3/ancillary/pulse_sep_thresh", "rx_processing_a2/toploc", "rx_processing_a4/ancillary/rx_use_fixed_thresholds", "geolocation/sensitivity_a2", "rx_processing_a1/ancillary/energy_thresh", "rx_processing_a5/rx_modeenergytobotloc", "geolocation/lon_highestreturn_a6", "rx_processing_a1/min_detection_threshold", "rx_processing_a1/ancillary/rx_sentinel_location", "rx_processing_a1/rx_nummodes", "rx_processing_a6/zcross", "rx_processing_a4/rx_modeenergytobotloc", "selected_mode", "rx_processing_a5/botloc", "latitude_bin0_error", "rx_processing_a3/search_start", "rx_processing_a5/rx_modelocalenergyabovemean", "rx_1gaussfit/ancillary/mpfit_tolerance", "geolocation/lons_allmodes_a4", "rx_1gaussfit/rx_gwidth", "land_cover_data/pft_class", "rx_processing_a4/rx_cumulative", "geolocation/lat_lowestmode_a5", "rx_processing_a3/rx_algrunflag", "rx_processing_a3/ancillary/rx_smoothing_width_zcross", "rx_processing_a4/toploc", "rx_processing_a6/stddev", "rx_processing_a1/ancillary/ampval_limit2", "rx_assess/mean", "rx_processing_a4/botloc_amp", "geolocation/elev_lowestmode_a2", "rx_processing_a1/ancillary/preprocessor_threshold", "rx_processing_a5/smoothwidth_zcross", "rx_processing_a1/zcross", "rx_processing_a1/back_threshold", "rx_processing_a6/smoothwidth", "geolocation/lon_lowestmode_a2", "rx_processing_a4/ancillary/rx_sentinel_location", "geolocation/lat_lowestmode_a3", "rx_processing_a1/ancillary/rx_front_threshold", "rx_processing_a2/smoothwidth_zcross", "rx_processing_a6/ancillary/ampval_limit3", "rx_processing_a2/search_end", "rx_processing_a4/ancillary/rx_smoothing_width_locs", "rx_processing_a3/zcross", "rx_processing_a4/rx_modelocalenergyabovemean", "rx_processing_a2/botloc", "ancillary/l2a_alg_count", "rx_processing_a6/energy_sm", "rx_processing_a2/front_threshold", "land_cover_data/urban_proportion", "rx_processing_a6/search_start", "rx_processing_a2/ancillary/rx_searchsize", "sensitivity", "rx_processing_a5/ancillary/rx_front_threshold", "geolocation/num_detectedmodes_a4", "geolocation/sensitivity_a6", "geolocation/lats_allmodes_a5", "geolocation/lon_lowestmode_a3", "rx_processing_a6/ancillary/rx_front_threshold", "rx_processing_a3/botloc_amp", "rx_processing_a4/back_threshold", "rx_processing_a3/rx_modelocalenergy", "geolocation/quality_flag_a5", "rx_processing_a3/ancillary/rx_use_fixed_thresholds", "rx_processing_a6/rx_modewidths", "rx_processing_a2/min_detection_threshold", "geolocation/elev_highestreturn_a3", "geolocation/lon_highestreturn_a2", "rx_processing_a6/zcross0", "rx_processing_a1/rx_modelocalenergy", "rx_processing_a4/rx_iwaveamps", "rx_processing_a3/ancillary/rx_subbin_resolution", "rx_processing_a3/mean", "lon_highestreturn", "rx_processing_a3/smoothwidth_zcross", "rx_processing_a4/peak", "geolocation/num_detectedmodes_a6", "rx_processing_a2/zcross", "rx_processing_a6/ancillary/preprocessor_threshold", "rx_processing_a3/mean_sm", "rx_processing_a2/rx_modewidths", "digital_elevation_model", "land_cover_data/landsat_water_persistence", "geolocation/lat_lowestmode_a4", "rx_processing_a5/selected_mode", "rx_1gaussfit/ancillary/rx_constraint_gamplitude_lower", "rx_1gaussfit/rx_gflag", "rx_processing_a6/botloc", "rx_processing_a5/rx_iwaveamps", "rx_processing_a4/ancillary/cumulative_energy_minimum", "rx_processing_a4/ancillary/pulse_sep_thresh", "rx_assess/quality_flag", "rx_processing_a4/rx_modewidths", "rx_processing_a3/ancillary/botlocdist_limit2", "rx_processing_a3/ancillary/enable_select_mode", "rx_processing_a6/search_end", "rx_processing_a6/rx_modelocalenergyabovemean", "geolocation/elev_highestreturn_a4", "rx_processing_a2/ancillary/cumulative_energy_minimum", "rx_processing_a5/search_end", "geolocation/lats_allmodes_a2", "geolocation/quality_flag_a2", "rx_1gaussfit/ancillary/rx_constraint_gwidth_lower", "rx_processing_a6/rx_nummodes", "rx_processing_a5/rx_modelocalenergy", "rx_processing_a2/ancillary/rx_sentinel_location", "rx_processing_a3/zcross0", "rx_processing_a3/sd_sm", "land_cover_data/leaf_on_cycle", "rx_processing_a3/front_threshold", "rx_1gaussfit/ancillary/mpfit_max_func_evals", "rx_processing_a3/ancillary/ampval_limit3", "rx_processing_a1/zcross0", "rx_processing_a5/ancillary/rx_sentinel_location", "rx_assess/rx_clipbin0", "rx_processing_a1/botloc", "shot_number", "rx_processing_a5/sd_sm", "rx_processing_a6/botloc_amp", "geolocation/elev_highestreturn_a6", "digital_elevation_model_srtm", "rx_1gaussfit/ancillary/rx_mean_noise_level", "rx_processing_a2/rx_iwaveamps", "rx_processing_a6/ancillary/amp_thresh", "rx_processing_a6/ancillary/ampval_limit2", "channel", "rx_processing_a2/ancillary/enable_select_mode", "rx_processing_a3/pk_sm", "rx_assess/rx_maxamp", "rx_assess/ancillary/rx_ampbounds_ul", "rx_processing_a6/rx_modelocalenergy", "land_cover_data/landsat_treecover", "rx_assess/rx_clipbin_count", "rx_processing_a6/lastmodeenergy", "geolocation/latitude_1gfit", "geolocation/elevation_1gfit", "rx_processing_a3/ancillary/rx_smoothing_width_locs", "rx_processing_a1/smoothwidth", "rx_processing_a6/rx_modeamps", "rx_processing_a2/ancillary/cumulative_energy_thresh", "rx_processing_a1/botloc_amp", "rx_processing_a3/energy_sm", "rx_processing_a2/search_start", "rx_processing_a4/ancillary/botlocdist_limit1", "rx_processing_a3/smoothwidth", "rx_processing_a6/min_detection_threshold", "geolocation/lat_lowestmode_a6", "rh", "rx_processing_a4/ancillary/enable_select_mode", "rx_processing_a4/mean", "rx_processing_a4/zcross_localenergy", "geolocation/elev_highestreturn_a5", "rx_processing_a1/selected_mode", "rx_processing_a4/ancillary/ampval_limit2", "geolocation/lon_highestreturn_a5", "rx_processing_a2/rx_modelocalslope", "rx_processing_a5/selected_mode_flag", "geolocation/lon_highestreturn_a4", "mean_sea_surface", "geolocation/lat_lowestreturn_a2", "surface_flag", "rx_processing_a5/ancillary/rx_back_threshold", "rx_processing_a5/peak", "rx_processing_a2/back_threshold", "geolocation/sensitivity_a4", "geolocation/lat_lowestreturn_a3", "rx_processing_a3/zcross_localenergy", "rx_processing_a2/min_detection_energy", "geolocation/energy_lowestmode_a5", "rx_processing_a3/ancillary/rx_front_threshold", "rx_processing_a4/energy_sm", "rx_processing_a5/ancillary/botlocdist_limit3", "geolocation/stale_return_flag", "geolocation/lats_allmodes_a4", "rx_processing_a3/ancillary/amp_thresh", "rx_processing_a5/zcross_localenergy", "rx_processing_a4/selected_mode_flag", "geolocation/lat_highestreturn_a1", "master_int", "rx_processing_a2/zcross_amp", "geolocation/lat_highestreturn_a3", "rx_assess/ancillary/rx_ampbounds_ll", "rx_processing_a3/ancillary/preprocessor_threshold", "rx_processing_a6/ancillary/rx_max_mode_count", "rx_processing_a5/ancillary/amp_thresh", "rx_1gaussfit/rx_gloc_error", "rx_processing_a2/ancillary/rx_max_mode_count", "geolocation/lat_highestreturn_a2", "land_cover_data/urban_focal_window_size", "rx_processing_a2/smoothwidth", "rx_processing_a3/ancillary/cumulative_energy_minimum", "rx_1gaussfit/ancillary/rx_smoothwidth", "rx_processing_a4/zcross0", "rx_processing_a3/rx_modelocalslope", "rx_processing_a6/ancillary/rx_back_threshold", "geolocation/lats_allmodes_a1", "geolocation/lons_allmodes_a1", "geolocation/lon_lowestreturn_a3", "rx_processing_a1/zcross_amp", "lat_lowestmode", "geolocation/lat_lowestreturn_a4", "rx_processing_a5/front_threshold", "geolocation/lon_highestreturn_a1", "rx_processing_a2/ancillary/pulse_sep_thresh", "rx_processing_a1/ancillary/botlocdist_limit1", "geolocation/sensitivity_a3", "rx_assess/rx_maxpeakloc", "rx_processing_a5/ancillary/preprocessor_threshold", "geolocation/rh_a5", "rx_1gaussfit/ancillary/rx_constraint_gwidth_upper", "geolocation/elev_lowestmode_a4", "rx_processing_a1/mean", "geolocation/lat_lowestmode_a1", "land_cover_data/leaf_on_doy", "geolocation/lon_lowestreturn_a5", "longitude_bin0_error", "geolocation/elev_lowestreturn_a1", "rx_processing_a2/ancillary/botlocdist_limit2", "geolocation/energy_lowestmode_a1", "geolocation/elev_lowestmode_a6", "rx_processing_a1/ancillary/botlocdist_limit3", "rx_processing_a5/min_detection_energy", "rx_processing_a6/min_detection_energy", "rx_processing_a4/ancillary/amp_thresh", "rx_1gaussfit/rx_gloc", "rx_processing_a6/mean_sm", "rx_assess/ancillary/rx_clipamp", "rx_processing_a1/rx_modelocalenergyabovemean", "rx_processing_a3/peak", "rx_processing_a1/rx_modewidths", "geolocation/num_detectedmodes_a3", "geolocation/elev_lowestreturn_a4", "rx_processing_a3/rx_modewidths", "rx_processing_a4/ancillary/cumulative_energy_thresh", "geolocation/lat_lowestreturn_a1", "rx_processing_a1/rx_modelocs", "rx_processing_a4/smoothwidth_zcross", "rx_processing_a6/selected_mode_flag", "rx_processing_a1/ancillary/rx_smoothing_width_locs", "rx_processing_a4/rx_algrunflag", "rx_1gaussfit/rx_gamplitude", "rx_processing_a1/ancillary/rx_subbin_resolution", "rx_processing_a6/rx_modeenergytobotloc", "rx_processing_a2/ancillary/ampval_limit3", "rx_processing_a6/mean", "geolocation/elevs_allmodes_a6", "rx_1gaussfit/rx_gchisq", "geolocation/elev_lowestmode_a3", "geolocation/energy_lowestmode_a4", "rx_processing_a3/rx_modelocalenergyabovemean", "geolocation/elev_lowestreturn_a5", "rx_processing_a5/ancillary/rx_smoothing_width_zcross", "rx_processing_a2/ancillary/rx_smoothing_width_locs", "rx_processing_a1/pk_sm", "geolocation/lons_allmodes_a3", "geolocation/num_detectedmodes_a5", "rx_processing_a2/energy_sm", "land_cover_data/modis_treecover", "rx_1gaussfit/rx_gbias_error", "rx_processing_a4/botloc", "rx_processing_a1/ancillary/cumulative_energy_thresh", "geolocation/lat_lowestmode_a2", "geolocation/rh_a2", "rx_processing_a2/ancillary/amp_thresh", "rx_processing_a2/ancillary/botlocdist_limit3", "rx_processing_a2/lastmodeenergy", "rx_processing_a3/ancillary/energy_thresh", "rx_processing_a1/ancillary/rx_max_mode_count", "geolocation/elevs_allmodes_a1", "rx_processing_a6/ancillary/rx_smoothing_width_zcross", "rx_processing_a4/stddev", "rx_processing_a5/toploc", "rx_processing_a5/ancillary/rx_use_fixed_thresholds", "rx_assess/ancillary/smoothing_width_locs", "geolocation/longitude_1gfit", "geolocation/lons_allmodes_a6", "rx_1gaussfit/rx_gwidth_error", "rx_processing_a5/ancillary/ampval_limit3", "rx_processing_a5/toploc_miss", "rx_processing_a1/min_detection_energy", "rx_processing_a3/lastmodeenergy", "rx_processing_a3/rx_iwaveamps", "rx_processing_a3/ancillary/ampval_limit2", "geolocation/sensitivity_a5", "rx_processing_a4/selected_mode", "rx_processing_a4/search_end", "rx_processing_a2/ancillary/rx_front_threshold", "rx_processing_a4/search_start", "geolocation/elev_lowestmode_a1", "rx_processing_a5/rx_modeamps", "rx_processing_a6/ancillary/energy_thresh", "rx_processing_a2/ancillary/rx_smoothing_width_zcross", "rx_processing_a6/ancillary/botlocdist_limit2", "rx_processing_a4/ancillary/botlocdist_limit3", "rx_1gaussfit/rx_gbias", "rx_processing_a5/mean_sm", "rx_processing_a6/ancillary/rx_smoothing_width_locs", "rx_processing_a1/ancillary/rx_use_fixed_thresholds", "rx_processing_a4/rx_modelocalslope", "beam", "rx_processing_a6/front_threshold", "rx_processing_a3/toploc_miss", "rx_processing_a5/rx_modewidths", "rx_processing_a3/ancillary/rx_searchsize", "rx_processing_a4/ancillary/rx_back_threshold", "rx_processing_a1/ancillary/ampval_limit3", "rx_processing_a5/ancillary/pulse_sep_thresh", "rx_processing_a4/ancillary/preprocessor_threshold", "rx_processing_a2/zcross_localenergy", "rx_processing_a4/rx_modeamps", "rx_processing_a2/selected_mode_flag", "rx_processing_a4/ancillary/energy_thresh", "rx_processing_a2/rx_modelocalenergyabovemean", "geolocation/elev_lowestreturn_a3", "rx_processing_a6/rx_algrunflag", "rx_processing_a3/ancillary/rx_sentinel_location", "rx_processing_a5/ancillary/rx_subbin_resolution", "rx_processing_a6/pk_sm", "rx_processing_a4/pk_sm", "geolocation/rh_a3", "rx_processing_a4/min_detection_energy", "rx_processing_a4/zcross", "rx_processing_a4/smoothwidth", "rx_processing_a2/ancillary/rx_back_threshold", "rx_processing_a3/rx_modeamps", "rx_processing_a5/energy_sm", "lon_lowestmode", "rx_processing_a6/rx_iwaveamps", "rx_processing_a5/zcross_amp", "rx_processing_a1/ancillary/pulse_sep_thresh", "rx_processing_a6/ancillary/rx_sentinel_location", "rx_processing_a3/ancillary/cumulative_energy_thresh", "rx_processing_a1/smoothwidth_zcross", "degrade_flag", "geolocation/lons_allmodes_a5", "rx_processing_a5/rx_cumulative", "rx_processing_a4/ancillary/rx_front_threshold", "rx_processing_a1/front_threshold", "geolocation/quality_flag_a3", "rx_processing_a1/stddev", "rx_processing_a3/rx_modelocs", "rx_processing_a2/stddev", "rx_processing_a6/smoothwidth_zcross", "rx_processing_a3/botloc", "rx_processing_a5/ancillary/cumulative_energy_minimum", "rx_processing_a3/rx_nummodes", "rx_processing_a2/mean_sm", "rx_processing_a1/rx_modelocalslope", "geolocation/lats_allmodes_a6", "rx_processing_a1/sd_sm", "geolocation/lon_lowestreturn_a2", "geolocation/lon_lowestreturn_a4", "rx_processing_a2/mean", "rx_processing_a6/toploc", "elevation_bin0_error", "rx_processing_a5/ancillary/rx_max_mode_count", "land_cover_data/modis_nonvegetated", "rx_processing_a1/mean_sm", "geolocation/lat_lowestreturn_a6", "rx_processing_a5/zcross", "rx_processing_a4/front_threshold", "rx_processing_a1/toploc_miss", "rx_processing_a1/ancillary/cumulative_energy_minimum", "rx_processing_a1/rx_cumulative", "elevation_bias_flag", "rx_processing_a2/rx_modeamps", "rx_processing_a6/ancillary/botlocdist_limit1", "geolocation/rh_a4", "rx_processing_a5/search_start", "rx_processing_a1/peak", "rx_processing_a5/ancillary/cumulative_energy_thresh", "energy_total", "land_cover_data/leaf_off_flag", "rx_processing_a5/mean", "rx_processing_a6/ancillary/enable_select_mode", "rx_processing_a6/rx_modelocalslope", "rx_processing_a5/ancillary/rx_smoothing_width_locs", "rx_processing_a5/back_threshold", "rx_processing_a2/botloc_amp", "land_cover_data/modis_treecover_sd", "geolocation/elevs_allmodes_a4", "geolocation/lon_lowestmode_a5", "geolocation/quality_flag_a1", "rx_processing_a6/ancillary/cumulative_energy_minimum", "rx_processing_a2/pk_sm", "rx_processing_a5/ancillary/rx_searchsize", "rx_processing_a3/rx_modeenergytobotloc", "rx_assess/ocean_calibration_shot_flag", "rx_processing_a3/ancillary/rx_max_mode_count", "geolocation/elev_lowestreturn_a2", "rx_processing_a4/rx_nummodes", "rx_processing_a2/rx_nummodes", "num_detectedmodes", "geolocation/energy_lowestmode_a2", "rx_processing_a5/botloc_amp", "rx_processing_a2/rx_modeenergytobotloc", "rx_processing_a4/sd_sm", "geolocation/elev_lowestmode_a5", "rx_processing_a2/rx_modelocalenergy", "rx_processing_a2/rx_cumulative", "rx_assess/rx_assess_flag", "rx_processing_a5/ancillary/ampval_limit2", "geolocation/lat_lowestreturn_a5", "rx_processing_a5/rx_algrunflag", "rx_processing_a2/ancillary/energy_thresh", "rx_processing_a1/rx_algrunflag", "rx_processing_a4/zcross_amp", "rx_processing_a5/min_detection_threshold", "rx_processing_a2/ancillary/ampval_limit2", "rx_processing_a6/rx_modelocs", "rx_1gaussfit/rx_gamplitude_error", "geolocation/sensitivity_a1", "land_cover_data/leaf_off_doy", "rx_processing_a1/ancillary/enable_select_mode", "rx_processing_a4/ancillary/botlocdist_limit2", "solar_elevation", "land_cover_data/region_class", "geolocation/elevs_allmodes_a2", "rx_processing_a1/rx_modeamps", "rx_processing_a4/lastmodeenergy", "rx_1gaussfit/rx_giters", "rx_processing_a4/rx_modelocalenergy", "rx_processing_a1/search_end", "geolocation/energy_lowestmode_a3", "rx_processing_a1/zcross_localenergy", "rx_processing_a3/back_threshold", "rx_processing_a5/rx_nummodes", "geolocation/elev_lowestreturn_a6", "selected_mode_flag", "elev_highestreturn", "rx_processing_a4/rx_modelocs", "solar_azimuth", "rx_processing_a6/toploc_miss", "rx_processing_a1/ancillary/rx_back_threshold", "geolocation/num_detectedmodes_a2", "rx_processing_a4/min_detection_threshold", "rx_processing_a3/zcross_amp", "selected_algorithm", "geolocation/lon_highestreturn_a3", "rx_processing_a5/ancillary/botlocdist_limit1", "rx_processing_a3/stddev", "geolocation/lon_lowestmode_a1", "rx_processing_a3/min_detection_threshold", "rx_processing_a5/smoothwidth", "rx_1gaussfit/ancillary/rx_constraint_gloc_lower", "rx_processing_a2/rx_algrunflag", "rx_processing_a4/ancillary/rx_searchsize", "rx_assess/sd_corrected", "rx_processing_a6/zcross_amp", "rx_processing_a3/search_end", "quality_flag", "rx_assess/ancillary/rx_ringthresh", "rx_processing_a2/selected_mode", "geolocation/lons_allmodes_a2", "rx_processing_a1/ancillary/amp_thresh", "rx_processing_a5/ancillary/energy_thresh", "rx_processing_a4/toploc_miss", "rx_processing_a3/toploc", "rx_processing_a2/ancillary/botlocdist_limit1", "rx_processing_a2/peak", "rx_processing_a1/lastmodeenergy", "rx_processing_a4/ancillary/rx_smoothing_width_zcross", "geolocation/quality_flag_a4", "rx_processing_a5/zcross0", "rx_processing_a4/mean_sm", "rx_processing_a6/back_threshold", "rx_1gaussfit/ancillary/mpfit_maxiters", "rx_assess/mean_64kadjusted"], "GEDI_L2B": ["rx_processing/rg_eg_flag_a4", "rx_processing/rg_eg_gamma_error_a5", "rx_processing/rg_eg_gamma_error_a1", "rx_processing/rg_error_a3", "rx_processing/rg_eg_amplitude_a2", "geolocation/local_beam_elevation", "ancillary/rg_eg_constraint_center_buffer", "rx_processing/rx_energy_a6", "ancillary/tx_noise_stddev_multiplier", "pgap_theta_z", "rx_processing/rg_eg_center_error_a5", "rx_processing/pgap_theta_a4", "land_cover_data/modis_nonvegetated", "geolocation/longitude_bin0_error", "rx_processing/rg_error_a1", "geolocation/elev_highestreturn", "land_cover_data/landsat_water_persistence", "land_cover_data/leaf_on_doy", "rx_processing/algorithmrun_flag_a5", "geolocation/lon_lowestmode", "rx_processing/rx_energy_a4", "geolocation/digital_elevation_model", "rhov", "rx_processing/rg_a5", "rx_processing/rg_error_a2", "geolocation/longitude_lastbin_error", "rx_processing/rg_a6", "rx_processing/rg_eg_gamma_a1", "l2b_quality_flag", "rx_processing/rg_eg_amplitude_error_a4", "rx_processing/rg_eg_amplitude_a3", "rx_processing/pgap_theta_error_a3", "land_cover_data/leaf_off_flag", "rx_processing/rv_a2", "geolocation/lon_highestreturn", "ancillary/dz", "master_frac", "rx_processing/rg_eg_niter_a1", "l2a_quality_flag", "rx_sample_count", "rx_processing/rg_a4", "pavd_z", "geolocation/lat_highestreturn", "land_cover_data/modis_treecover_sd", "rx_processing/rg_eg_amplitude_error_a2", "rx_processing/rg_eg_center_a2", "rx_processing/rg_eg_center_error_a6", "geolocation/solar_azimuth", "rv", "rx_processing/shot_number", "rx_processing/rg_eg_sigma_a3", "rx_processing/rg_eg_center_a1", "rx_processing/rg_eg_sigma_error_a5", "rx_processing/rg_eg_flag_a6", "rx_processing/rg_eg_flag_a1", "rx_sample_start_index", "rx_processing/pgap_theta_a1", "rx_processing/rg_a2", "omega", "rx_processing/pgap_theta_error_a5", "rx_processing/pgap_theta_error_a4", "land_cover_data/leaf_on_cycle", "rx_processing/rg_eg_niter_a5", "ancillary/rg_eg_mpfit_max_func_evals", "rx_processing/rg_eg_center_error_a4", "rx_processing/rg_eg_gamma_a2", "num_detectedmodes", "rhov_error", "rx_processing/pgap_theta_error_a6", "rx_processing/rg_eg_center_error_a3", "rhog_error", "rx_processing/rg_eg_gamma_a5", "shot_number", "geolocation/latitude_bin0_error", "rx_processing/rg_eg_center_a5", "rx_processing/rg_eg_flag_a3", "fhd_normal", "rx_processing/rg_error_a4", "rx_processing/rg_eg_sigma_error_a2", "rx_processing/algorithmrun_flag_a3", "land_cover_data/modis_treecover", "channel", "rx_processing/rg_eg_gamma_error_a2", "cover", "geolocation/lat_lowestmode", "rx_processing/rg_eg_chisq_a4", "rx_processing/rg_eg_flag_a5", "rx_range_highestreturn", "geolocation/longitude_lastbin", "rx_processing/rg_eg_sigma_a1", "land_cover_data/modis_nonvegetated_sd", "land_cover_data/landsat_treecover", "rx_processing/rg_eg_gamma_error_a4", "rx_processing/rg_eg_amplitude_error_a5", "rx_processing/rg_eg_gamma_a3", "rx_processing/algorithmrun_flag_a2", "geolocation/latitude_lastbin", "rx_processing/rg_error_a5", "geolocation/elevation_bin0_error", "land_cover_data/leaf_off_doy", "rx_processing/rv_a4", "rx_processing/rv_a6", "rx_processing/rx_energy_a1", "rhog", "geolocation/shot_number", "geolocation/solar_elevation", "land_cover_data/region_class", "rx_processing/rv_a3", "rx_processing/rg_eg_amplitude_a4", "rx_processing/rg_eg_gamma_a6", "rx_processing/rx_energy_a5", "rx_processing/algorithmrun_flag_a4", "rx_processing/rg_eg_gamma_a4", "geolocation/latitude_bin0", "selected_mode", "geolocation/elevation_lastbin_error", "rx_processing/rv_a5", "rx_processing/pgap_theta_error_a2", "rx_processing/rv_a1", "rx_processing/rg_eg_niter_a3", "rx_processing/rg_eg_flag_a2", "selected_mode_flag", "land_cover_data/pft_class", "rx_processing/rg_eg_chisq_a1", "rx_processing/rg_eg_center_a3", "rx_processing/rg_eg_center_a6", "ancillary/rg_eg_mpfit_tolerance", "rx_processing/rg_eg_amplitude_a6", "rx_processing/rg_eg_center_error_a1", "algorithmrun_flag", "rx_processing/rg_eg_center_error_a2", "ancillary/rg_eg_mpfit_maxiters", "geolocation/height_lastbin", "rx_processing/pgap_theta_a3", "rx_processing/algorithmrun_flag_a1", "rx_processing/pgap_theta_error_a1", "surface_flag", "geolocation/height_bin0", "rossg", "rx_processing/rx_energy_a3", "pai_z", "beam", "rx_processing/rx_energy_a2", "ancillary/maxheight_cuttoff", "rx_processing/pgap_theta_a6", "rx_processing/rg_eg_chisq_a3", "rx_processing/rg_error_a6", "rx_processing/rg_eg_chisq_a2", "geolocation/local_beam_azimuth", "rh100", "rx_processing/pgap_theta_a5", "rx_processing/rg_eg_gamma_error_a3", "rx_processing/algorithmrun_flag_a6", "rx_processing/rg_eg_sigma_a5", "rx_processing/rg_a1", "rx_processing/rg_eg_niter_a6", "pgap_theta", "rx_processing/rg_eg_center_a4", "rx_processing/rg_eg_amplitude_a1", "geolocation/latitude_lastbin_error", "rx_processing/rg_eg_niter_a2", "rx_processing/rg_eg_amplitude_error_a6", "rx_processing/pgap_theta_a2", "cover_z", "rx_processing/rg_eg_amplitude_error_a1", "rx_processing/rg_eg_sigma_error_a4", "ancillary/l2a_alg_count", "master_int", "pai", "rx_processing/rg_a3", "land_cover_data/urban_proportion", "rx_processing/rg_eg_gamma_error_a6", "rx_processing/rg_eg_sigma_a4", "geolocation/elevation_lastbin", "geolocation/longitude_bin0", "sensitivity", "rx_processing/rg_eg_sigma_a2", "stale_return_flag", "rx_processing/rg_eg_chisq_a6", "land_cover_data/urban_focal_window_size", "rx_processing/rg_eg_niter_a4", "rg", "pgap_theta_error", "rx_processing/rg_eg_sigma_error_a3", "geolocation/degrade_flag", "selected_l2a_algorithm", "rx_processing/rg_eg_sigma_error_a1", "geolocation/elev_lowestmode", "geolocation/delta_time", "rx_processing/rg_eg_amplitude_error_a3", "selected_rg_algorithm", "ancillary/signal_search_buff", "rx_processing/rg_eg_chisq_a5", "rx_processing/rg_eg_amplitude_a5", "rx_processing/rg_eg_sigma_a6", "geolocation/elevation_bin0", "rx_processing/rg_eg_sigma_error_a6"]}

# %%
field
# Out:
# {'GEDI_L1B': ['geolocation/altitude_instrument',
#   'geolocation/local_beam_elevation',
#   'tx_sample_start_index',
#   'nsemean_odd',
#   'ancillary/master_time_epoch',
#   'noise_stddev_corrected',
#   'tx_pulseflag',
#   'geolocation/longitude_bin0_error',
#   'selection_stretchers_x',
#   'nsemean_even',
#   'geolocation/latitude_instrument',
#   'geolocation/digital_elevation_model',
#   'geolocation/longitude_instrument_error',
#   'geolocation/longitude_lastbin_error',
#   'tx_egsigma',
#   'geolocation/neutat_delay_total_bin0',
#   'rx_energy',
#   'master_frac',
#   'rx_sample_count',
#   'rxwaveform',
#   'tx_gloc',
#   'ancillary/mean_samples',
#   'geolocation/longitude_instrument',
#   'tx_eggamma_error',
#   'rx_offset',
#   'tx_egbias_error',
#   'geolocation/bounce_time_offset_lastbin',
#   'all_samples_sum',
#   'geophys_corr/tide_load',
#   'geolocation/solar_azimuth',
#   'geolocation/mean_sea_surface',
#   'geolocation/neutat_delay_total_lastbin',
#   'th_left_used',
#   'rx_sample_start_index',
#   'geophys_corr/tide_ocean',
#   'geophys_corr/tide_ocean_pole',
#   'tx_eggamma',
#   'geophys_corr/tide_pole',
#   'tx_sample_count',
#   'geolocation/surface_type',
#   'geolocation/neutat_delay_derivative_bin0',
#   'geolocation/digital_elevation_model_srtm',
#   'shot_number',
#   'txwaveform',
#   'geolocation/latitude_bin0_error',
#   'geolocation/altitude_instrument_error',
#   'channel',
#   'geolocation/longitude_lastbin',
#   'geolocation/latitude_lastbin',
#   'geolocation/elevation_bin0_error',
#   'geolocation/shot_number',
#   'geolocation/solar_elevation',
#   'geolocation/local_beam_elevation_error',
#   'tx_egamplitude',
#   'geolocation/latitude_bin0',
#   'geolocation/elevation_lastbin_error',
#   'ancillary/smoothing_width',
#   'geolocation/latitude_instrument_error',
#   'tx_egbias',
#   'geolocation/bounce_time_offset_bin0_error',
#   'geolocation/bounce_time_offset_bin0',
#   'rx_open',
#   'beam',
#   'geolocation/local_beam_azimuth',
#   'tx_egflag',
#   'tx_egsigma_error',
#   'geolocation/bounce_time_offset_lastbin_error',
#   'tx_gloc_error',
#   'geophys_corr/geoid',
#   'selection_stretchers_y',
#   'geolocation/latitude_lastbin_error',
#   'master_int',
#   'geolocation/range_bias_correction',
#   'geolocation/elevation_lastbin',
#   'geolocation/longitude_bin0',
#   'stale_return_flag',
#   'geolocation/delta_time',
#   'noise_mean_corrected',
#   'geolocation/local_beam_azimuth_error',
#   'geophys_corr/dynamic_atmosphere_correction',
#   'geophys_corr/delta_time',
#   'tx_egamplitude_error',
#   'geolocation/elevation_bin0',
#   'geolocation/neutat_delay_derivative_lastbin',
#   'geolocation/degrade',
#   'geophys_corr/tide_earth'],
#  'GEDI_L2A': ['rx_processing_a4/ancillary/rx_subbin_resolution',
#   'rx_processing_a6/ancillary/rx_use_fixed_thresholds',
#   'rx_processing_a1/rx_iwaveamps',
#   'rx_processing_a1/selected_mode_flag',
#   'rx_processing_a2/sd_sm',
#   'geolocation/elev_highestreturn_a2',
#   'rx_processing_a2/zcross0',
#   'geolocation/rh_a6',
#   'rx_processing_a2/ancillary/preprocessor_threshold',
#   'rx_processing_a4/ancillary/rx_max_mode_count',
#   'geolocation/elevs_allmodes_a3',
#   'rx_processing_a1/ancillary/rx_smoothing_width_zcross',
#   'rx_processing_a6/sd_sm',
#   'rx_processing_a3/rx_cumulative',
#   'geolocation/quality_flag_a6',
#   'lat_highestreturn',
#   'rx_1gaussfit/ancillary/rx_constraint_gloc_upper',
#   'rx_assess/ancillary/rx_pulsethresh',
#   'rx_processing_a3/selected_mode',
#   'rx_processing_a5/ancillary/enable_select_mode',
#   'geolocation/elev_highestreturn_a1',
#   'rx_processing_a1/toploc',
#   'rx_1gaussfit/ancillary/rx_estimate_bias',
#   'rx_processing_a1/search_start',
#   'rx_processing_a6/ancillary/rx_subbin_resolution',
#   'rx_processing_a6/zcross_localenergy',
#   'geolocation/energy_lowestmode_a6',
#   'master_frac',
#   'rx_processing_a4/ancillary/ampval_limit3',
#   'rx_processing_a6/selected_mode',
#   'geolocation/lat_highestreturn_a4',
#   'rx_processing_a1/ancillary/botlocdist_limit2',
#   'rx_processing_a3/min_detection_energy',
#   'rx_processing_a6/peak',
#   'rx_processing_a5/rx_modelocalslope',
#   'rx_processing_a6/ancillary/cumulative_energy_thresh',
#   'geolocation/lon_lowestmode_a6',
#   'rx_processing_a6/ancillary/pulse_sep_thresh',
#   'rx_processing_a5/lastmodeenergy',
#   'rx_1gaussfit/ancillary/rx_constraint_gamplitude_upper',
#   'geolocation/elevs_allmodes_a5',
#   'rx_assess/rx_energy',
#   'rx_processing_a6/rx_cumulative',
#   'delta_time',
#   'rx_processing_a2/rx_modelocs',
#   'rx_processing_a6/ancillary/rx_searchsize',
#   'elev_lowestmode',
#   'rx_processing_a3/selected_mode_flag',
#   'rx_processing_a5/pk_sm',
#   'rx_processing_a2/ancillary/rx_subbin_resolution',
#   'rx_processing_a5/ancillary/botlocdist_limit2',
#   'geolocation/lats_allmodes_a3',
#   'geolocation/lat_highestreturn_a5',
#   'geolocation/lon_lowestreturn_a6',
#   'rx_processing_a1/energy_sm',
#   'rx_processing_a5/stddev',
#   'rx_processing_a2/ancillary/rx_use_fixed_thresholds',
#   'geolocation/lon_lowestmode_a4',
#   'rx_processing_a3/ancillary/rx_back_threshold',
#   'geolocation/num_detectedmodes_a1',
#   'rx_processing_a3/ancillary/botlocdist_limit3',
#   'rx_processing_a1/ancillary/rx_searchsize',
#   'rx_processing_a2/toploc_miss',
#   'geolocation/lat_highestreturn_a6',
#   'rx_processing_a3/ancillary/botlocdist_limit1',
#   'rx_processing_a5/rx_modelocs',
#   'rx_processing_a6/ancillary/botlocdist_limit3',
#   'geolocation/lon_lowestreturn_a1',
#   'geolocation/rh_a1',
#   'land_cover_data/modis_nonvegetated_sd',
#   'rx_processing_a1/rx_modeenergytobotloc',
#   'rx_processing_a3/ancillary/pulse_sep_thresh',
#   'rx_processing_a2/toploc',
#   'rx_processing_a4/ancillary/rx_use_fixed_thresholds',
#   'geolocation/sensitivity_a2',
#   'rx_processing_a1/ancillary/energy_thresh',
#   'rx_processing_a5/rx_modeenergytobotloc',
#   'geolocation/lon_highestreturn_a6',
#   'rx_processing_a1/min_detection_threshold',
#   'rx_processing_a1/ancillary/rx_sentinel_location',
#   'rx_processing_a1/rx_nummodes',
#   'rx_processing_a6/zcross',
#   'rx_processing_a4/rx_modeenergytobotloc',
#   'selected_mode',
#   'rx_processing_a5/botloc',
#   'latitude_bin0_error',
#   'rx_processing_a3/search_start',
#   'rx_processing_a5/rx_modelocalenergyabovemean',
#   'rx_1gaussfit/ancillary/mpfit_tolerance',
#   'geolocation/lons_allmodes_a4',
#   'rx_1gaussfit/rx_gwidth',
#   'land_cover_data/pft_class',
#   'rx_processing_a4/rx_cumulative',
#   'geolocation/lat_lowestmode_a5',
#   'rx_processing_a3/rx_algrunflag',
#   'rx_processing_a3/ancillary/rx_smoothing_width_zcross',
#   'rx_processing_a4/toploc',
#   'rx_processing_a6/stddev',
#   'rx_processing_a1/ancillary/ampval_limit2',
#   'rx_assess/mean',
#   'rx_processing_a4/botloc_amp',
#   'geolocation/elev_lowestmode_a2',
#   'rx_processing_a1/ancillary/preprocessor_threshold',
#   'rx_processing_a5/smoothwidth_zcross',
#   'rx_processing_a1/zcross',
#   'rx_processing_a1/back_threshold',
#   'rx_processing_a6/smoothwidth',
#   'geolocation/lon_lowestmode_a2',
#   'rx_processing_a4/ancillary/rx_sentinel_location',
#   'geolocation/lat_lowestmode_a3',
#   'rx_processing_a1/ancillary/rx_front_threshold',
#   'rx_processing_a2/smoothwidth_zcross',
#   'rx_processing_a6/ancillary/ampval_limit3',
#   'rx_processing_a2/search_end',
#   'rx_processing_a4/ancillary/rx_smoothing_width_locs',
#   'rx_processing_a3/zcross',
#   'rx_processing_a4/rx_modelocalenergyabovemean',
#   'rx_processing_a2/botloc',
#   'ancillary/l2a_alg_count',
#   'rx_processing_a6/energy_sm',
#   'rx_processing_a2/front_threshold',
#   'land_cover_data/urban_proportion',
#   'rx_processing_a6/search_start',
#   'rx_processing_a2/ancillary/rx_searchsize',
#   'sensitivity',
#   'rx_processing_a5/ancillary/rx_front_threshold',
#   'geolocation/num_detectedmodes_a4',
#   'geolocation/sensitivity_a6',
#   'geolocation/lats_allmodes_a5',
#   'geolocation/lon_lowestmode_a3',
#   'rx_processing_a6/ancillary/rx_front_threshold',
#   'rx_processing_a3/botloc_amp',
#   'rx_processing_a4/back_threshold',
#   'rx_processing_a3/rx_modelocalenergy',
#   'geolocation/quality_flag_a5',
#   'rx_processing_a3/ancillary/rx_use_fixed_thresholds',
#   'rx_processing_a6/rx_modewidths',
#   'rx_processing_a2/min_detection_threshold',
#   'geolocation/elev_highestreturn_a3',
#   'geolocation/lon_highestreturn_a2',
#   'rx_processing_a6/zcross0',
#   'rx_processing_a1/rx_modelocalenergy',
#   'rx_processing_a4/rx_iwaveamps',
#   'rx_processing_a3/ancillary/rx_subbin_resolution',
#   'rx_processing_a3/mean',
#   'lon_highestreturn',
#   'rx_processing_a3/smoothwidth_zcross',
#   'rx_processing_a4/peak',
#   'geolocation/num_detectedmodes_a6',
#   'rx_processing_a2/zcross',
#   'rx_processing_a6/ancillary/preprocessor_threshold',
#   'rx_processing_a3/mean_sm',
#   'rx_processing_a2/rx_modewidths',
#   'digital_elevation_model',
#   'land_cover_data/landsat_water_persistence',
#   'geolocation/lat_lowestmode_a4',
#   'rx_processing_a5/selected_mode',
#   'rx_1gaussfit/ancillary/rx_constraint_gamplitude_lower',
#   'rx_1gaussfit/rx_gflag',
#   'rx_processing_a6/botloc',
#   'rx_processing_a5/rx_iwaveamps',
#   'rx_processing_a4/ancillary/cumulative_energy_minimum',
#   'rx_processing_a4/ancillary/pulse_sep_thresh',
#   'rx_assess/quality_flag',
#   'rx_processing_a4/rx_modewidths',
#   'rx_processing_a3/ancillary/botlocdist_limit2',
#   'rx_processing_a3/ancillary/enable_select_mode',
#   'rx_processing_a6/search_end',
#   'rx_processing_a6/rx_modelocalenergyabovemean',
#   'geolocation/elev_highestreturn_a4',
#   'rx_processing_a2/ancillary/cumulative_energy_minimum',
#   'rx_processing_a5/search_end',
#   'geolocation/lats_allmodes_a2',
#   'geolocation/quality_flag_a2',
#   'rx_1gaussfit/ancillary/rx_constraint_gwidth_lower',
#   'rx_processing_a6/rx_nummodes',
#   'rx_processing_a5/rx_modelocalenergy',
#   'rx_processing_a2/ancillary/rx_sentinel_location',
#   'rx_processing_a3/zcross0',
#   'rx_processing_a3/sd_sm',
#   'land_cover_data/leaf_on_cycle',
#   'rx_processing_a3/front_threshold',
#   'rx_1gaussfit/ancillary/mpfit_max_func_evals',
#   'rx_processing_a3/ancillary/ampval_limit3',
#   'rx_processing_a1/zcross0',
#   'rx_processing_a5/ancillary/rx_sentinel_location',
#   'rx_assess/rx_clipbin0',
#   'rx_processing_a1/botloc',
#   'shot_number',
#   'rx_processing_a5/sd_sm',
#   'rx_processing_a6/botloc_amp',
#   'geolocation/elev_highestreturn_a6',
#   'digital_elevation_model_srtm',
#   'rx_1gaussfit/ancillary/rx_mean_noise_level',
#   'rx_processing_a2/rx_iwaveamps',
#   'rx_processing_a6/ancillary/amp_thresh',
#   'rx_processing_a6/ancillary/ampval_limit2',
#   'channel',
#   'rx_processing_a2/ancillary/enable_select_mode',
#   'rx_processing_a3/pk_sm',
#   'rx_assess/rx_maxamp',
#   'rx_assess/ancillary/rx_ampbounds_ul',
#   'rx_processing_a6/rx_modelocalenergy',
#   'land_cover_data/landsat_treecover',
#   'rx_assess/rx_clipbin_count',
#   'rx_processing_a6/lastmodeenergy',
#   'geolocation/latitude_1gfit',
#   'geolocation/elevation_1gfit',
#   'rx_processing_a3/ancillary/rx_smoothing_width_locs',
#   'rx_processing_a1/smoothwidth',
#   'rx_processing_a6/rx_modeamps',
#   'rx_processing_a2/ancillary/cumulative_energy_thresh',
#   'rx_processing_a1/botloc_amp',
#   'rx_processing_a3/energy_sm',
#   'rx_processing_a2/search_start',
#   'rx_processing_a4/ancillary/botlocdist_limit1',
#   'rx_processing_a3/smoothwidth',
#   'rx_processing_a6/min_detection_threshold',
#   'geolocation/lat_lowestmode_a6',
#   'rh',
#   'rx_processing_a4/ancillary/enable_select_mode',
#   'rx_processing_a4/mean',
#   'rx_processing_a4/zcross_localenergy',
#   'geolocation/elev_highestreturn_a5',
#   'rx_processing_a1/selected_mode',
#   'rx_processing_a4/ancillary/ampval_limit2',
#   'geolocation/lon_highestreturn_a5',
#   'rx_processing_a2/rx_modelocalslope',
#   'rx_processing_a5/selected_mode_flag',
#   'geolocation/lon_highestreturn_a4',
#   'mean_sea_surface',
#   'geolocation/lat_lowestreturn_a2',
#   'surface_flag',
#   'rx_processing_a5/ancillary/rx_back_threshold',
#   'rx_processing_a5/peak',
#   'rx_processing_a2/back_threshold',
#   'geolocation/sensitivity_a4',
#   'geolocation/lat_lowestreturn_a3',
#   'rx_processing_a3/zcross_localenergy',
#   'rx_processing_a2/min_detection_energy',
#   'geolocation/energy_lowestmode_a5',
#   'rx_processing_a3/ancillary/rx_front_threshold',
#   'rx_processing_a4/energy_sm',
#   'rx_processing_a5/ancillary/botlocdist_limit3',
#   'geolocation/stale_return_flag',
#   'geolocation/lats_allmodes_a4',
#   'rx_processing_a3/ancillary/amp_thresh',
#   'rx_processing_a5/zcross_localenergy',
#   'rx_processing_a4/selected_mode_flag',
#   'geolocation/lat_highestreturn_a1',
#   'master_int',
#   'rx_processing_a2/zcross_amp',
#   'geolocation/lat_highestreturn_a3',
#   'rx_assess/ancillary/rx_ampbounds_ll',
#   'rx_processing_a3/ancillary/preprocessor_threshold',
#   'rx_processing_a6/ancillary/rx_max_mode_count',
#   'rx_processing_a5/ancillary/amp_thresh',
#   'rx_1gaussfit/rx_gloc_error',
#   'rx_processing_a2/ancillary/rx_max_mode_count',
#   'geolocation/lat_highestreturn_a2',
#   'land_cover_data/urban_focal_window_size',
#   'rx_processing_a2/smoothwidth',
#   'rx_processing_a3/ancillary/cumulative_energy_minimum',
#   'rx_1gaussfit/ancillary/rx_smoothwidth',
#   'rx_processing_a4/zcross0',
#   'rx_processing_a3/rx_modelocalslope',
#   'rx_processing_a6/ancillary/rx_back_threshold',
#   'geolocation/lats_allmodes_a1',
#   'geolocation/lons_allmodes_a1',
#   'geolocation/lon_lowestreturn_a3',
#   'rx_processing_a1/zcross_amp',
#   'lat_lowestmode',
#   'geolocation/lat_lowestreturn_a4',
#   'rx_processing_a5/front_threshold',
#   'geolocation/lon_highestreturn_a1',
#   'rx_processing_a2/ancillary/pulse_sep_thresh',
#   'rx_processing_a1/ancillary/botlocdist_limit1',
#   'geolocation/sensitivity_a3',
#   'rx_assess/rx_maxpeakloc',
#   'rx_processing_a5/ancillary/preprocessor_threshold',
#   'geolocation/rh_a5',
#   'rx_1gaussfit/ancillary/rx_constraint_gwidth_upper',
#   'geolocation/elev_lowestmode_a4',
#   'rx_processing_a1/mean',
#   'geolocation/lat_lowestmode_a1',
#   'land_cover_data/leaf_on_doy',
#   'geolocation/lon_lowestreturn_a5',
#   'longitude_bin0_error',
#   'geolocation/elev_lowestreturn_a1',
#   'rx_processing_a2/ancillary/botlocdist_limit2',
#   'geolocation/energy_lowestmode_a1',
#   'geolocation/elev_lowestmode_a6',
#   'rx_processing_a1/ancillary/botlocdist_limit3',
#   'rx_processing_a5/min_detection_energy',
#   'rx_processing_a6/min_detection_energy',
#   'rx_processing_a4/ancillary/amp_thresh',
#   'rx_1gaussfit/rx_gloc',
#   'rx_processing_a6/mean_sm',
#   'rx_assess/ancillary/rx_clipamp',
#   'rx_processing_a1/rx_modelocalenergyabovemean',
#   'rx_processing_a3/peak',
#   'rx_processing_a1/rx_modewidths',
#   'geolocation/num_detectedmodes_a3',
#   'geolocation/elev_lowestreturn_a4',
#   'rx_processing_a3/rx_modewidths',
#   'rx_processing_a4/ancillary/cumulative_energy_thresh',
#   'geolocation/lat_lowestreturn_a1',
#   'rx_processing_a1/rx_modelocs',
#   'rx_processing_a4/smoothwidth_zcross',
#   'rx_processing_a6/selected_mode_flag',
#   'rx_processing_a1/ancillary/rx_smoothing_width_locs',
#   'rx_processing_a4/rx_algrunflag',
#   'rx_1gaussfit/rx_gamplitude',
#   'rx_processing_a1/ancillary/rx_subbin_resolution',
#   'rx_processing_a6/rx_modeenergytobotloc',
#   'rx_processing_a2/ancillary/ampval_limit3',
#   'rx_processing_a6/mean',
#   'geolocation/elevs_allmodes_a6',
#   'rx_1gaussfit/rx_gchisq',
#   'geolocation/elev_lowestmode_a3',
#   'geolocation/energy_lowestmode_a4',
#   'rx_processing_a3/rx_modelocalenergyabovemean',
#   'geolocation/elev_lowestreturn_a5',
#   'rx_processing_a5/ancillary/rx_smoothing_width_zcross',
#   'rx_processing_a2/ancillary/rx_smoothing_width_locs',
#   'rx_processing_a1/pk_sm',
#   'geolocation/lons_allmodes_a3',
#   'geolocation/num_detectedmodes_a5',
#   'rx_processing_a2/energy_sm',
#   'land_cover_data/modis_treecover',
#   'rx_1gaussfit/rx_gbias_error',
#   'rx_processing_a4/botloc',
#   'rx_processing_a1/ancillary/cumulative_energy_thresh',
#   'geolocation/lat_lowestmode_a2',
#   'geolocation/rh_a2',
#   'rx_processing_a2/ancillary/amp_thresh',
#   'rx_processing_a2/ancillary/botlocdist_limit3',
#   'rx_processing_a2/lastmodeenergy',
#   'rx_processing_a3/ancillary/energy_thresh',
#   'rx_processing_a1/ancillary/rx_max_mode_count',
#   'geolocation/elevs_allmodes_a1',
#   'rx_processing_a6/ancillary/rx_smoothing_width_zcross',
#   'rx_processing_a4/stddev',
#   'rx_processing_a5/toploc',
#   'rx_processing_a5/ancillary/rx_use_fixed_thresholds',
#   'rx_assess/ancillary/smoothing_width_locs',
#   'geolocation/longitude_1gfit',
#   'geolocation/lons_allmodes_a6',
#   'rx_1gaussfit/rx_gwidth_error',
#   'rx_processing_a5/ancillary/ampval_limit3',
#   'rx_processing_a5/toploc_miss',
#   'rx_processing_a1/min_detection_energy',
#   'rx_processing_a3/lastmodeenergy',
#   'rx_processing_a3/rx_iwaveamps',
#   'rx_processing_a3/ancillary/ampval_limit2',
#   'geolocation/sensitivity_a5',
#   'rx_processing_a4/selected_mode',
#   'rx_processing_a4/search_end',
#   'rx_processing_a2/ancillary/rx_front_threshold',
#   'rx_processing_a4/search_start',
#   'geolocation/elev_lowestmode_a1',
#   'rx_processing_a5/rx_modeamps',
#   'rx_processing_a6/ancillary/energy_thresh',
#   'rx_processing_a2/ancillary/rx_smoothing_width_zcross',
#   'rx_processing_a6/ancillary/botlocdist_limit2',
#   'rx_processing_a4/ancillary/botlocdist_limit3',
#   'rx_1gaussfit/rx_gbias',
#   'rx_processing_a5/mean_sm',
#   'rx_processing_a6/ancillary/rx_smoothing_width_locs',
#   'rx_processing_a1/ancillary/rx_use_fixed_thresholds',
#   'rx_processing_a4/rx_modelocalslope',
#   'beam',
#   'rx_processing_a6/front_threshold',
#   'rx_processing_a3/toploc_miss',
#   'rx_processing_a5/rx_modewidths',
#   'rx_processing_a3/ancillary/rx_searchsize',
#   'rx_processing_a4/ancillary/rx_back_threshold',
#   'rx_processing_a1/ancillary/ampval_limit3',
#   'rx_processing_a5/ancillary/pulse_sep_thresh',
#   'rx_processing_a4/ancillary/preprocessor_threshold',
#   'rx_processing_a2/zcross_localenergy',
#   'rx_processing_a4/rx_modeamps',
#   'rx_processing_a2/selected_mode_flag',
#   'rx_processing_a4/ancillary/energy_thresh',
#   'rx_processing_a2/rx_modelocalenergyabovemean',
#   'geolocation/elev_lowestreturn_a3',
#   'rx_processing_a6/rx_algrunflag',
#   'rx_processing_a3/ancillary/rx_sentinel_location',
#   'rx_processing_a5/ancillary/rx_subbin_resolution',
#   'rx_processing_a6/pk_sm',
#   'rx_processing_a4/pk_sm',
#   'geolocation/rh_a3',
#   'rx_processing_a4/min_detection_energy',
#   'rx_processing_a4/zcross',
#   'rx_processing_a4/smoothwidth',
#   'rx_processing_a2/ancillary/rx_back_threshold',
#   'rx_processing_a3/rx_modeamps',
#   'rx_processing_a5/energy_sm',
#   'lon_lowestmode',
#   'rx_processing_a6/rx_iwaveamps',
#   'rx_processing_a5/zcross_amp',
#   'rx_processing_a1/ancillary/pulse_sep_thresh',
#   'rx_processing_a6/ancillary/rx_sentinel_location',
#   'rx_processing_a3/ancillary/cumulative_energy_thresh',
#   'rx_processing_a1/smoothwidth_zcross',
#   'degrade_flag',
#   'geolocation/lons_allmodes_a5',
#   'rx_processing_a5/rx_cumulative',
#   'rx_processing_a4/ancillary/rx_front_threshold',
#   'rx_processing_a1/front_threshold',
#   'geolocation/quality_flag_a3',
#   'rx_processing_a1/stddev',
#   'rx_processing_a3/rx_modelocs',
#   'rx_processing_a2/stddev',
#   'rx_processing_a6/smoothwidth_zcross',
#   'rx_processing_a3/botloc',
#   'rx_processing_a5/ancillary/cumulative_energy_minimum',
#   'rx_processing_a3/rx_nummodes',
#   'rx_processing_a2/mean_sm',
#   'rx_processing_a1/rx_modelocalslope',
#   'geolocation/lats_allmodes_a6',
#   'rx_processing_a1/sd_sm',
#   'geolocation/lon_lowestreturn_a2',
#   'geolocation/lon_lowestreturn_a4',
#   'rx_processing_a2/mean',
#   'rx_processing_a6/toploc',
#   'elevation_bin0_error',
#   'rx_processing_a5/ancillary/rx_max_mode_count',
#   'land_cover_data/modis_nonvegetated',
#   'rx_processing_a1/mean_sm',
#   'geolocation/lat_lowestreturn_a6',
#   'rx_processing_a5/zcross',
#   'rx_processing_a4/front_threshold',
#   'rx_processing_a1/toploc_miss',
#   'rx_processing_a1/ancillary/cumulative_energy_minimum',
#   'rx_processing_a1/rx_cumulative',
#   'elevation_bias_flag',
#   'rx_processing_a2/rx_modeamps',
#   'rx_processing_a6/ancillary/botlocdist_limit1',
#   'geolocation/rh_a4',
#   'rx_processing_a5/search_start',
#   'rx_processing_a1/peak',
#   'rx_processing_a5/ancillary/cumulative_energy_thresh',
#   'energy_total',
#   'land_cover_data/leaf_off_flag',
#   'rx_processing_a5/mean',
#   'rx_processing_a6/ancillary/enable_select_mode',
#   'rx_processing_a6/rx_modelocalslope',
#   'rx_processing_a5/ancillary/rx_smoothing_width_locs',
#   'rx_processing_a5/back_threshold',
#   'rx_processing_a2/botloc_amp',
#   'land_cover_data/modis_treecover_sd',
#   'geolocation/elevs_allmodes_a4',
#   'geolocation/lon_lowestmode_a5',
#   'geolocation/quality_flag_a1',
#   'rx_processing_a6/ancillary/cumulative_energy_minimum',
#   'rx_processing_a2/pk_sm',
#   'rx_processing_a5/ancillary/rx_searchsize',
#   'rx_processing_a3/rx_modeenergytobotloc',
#   'rx_assess/ocean_calibration_shot_flag',
#   'rx_processing_a3/ancillary/rx_max_mode_count',
#   'geolocation/elev_lowestreturn_a2',
#   'rx_processing_a4/rx_nummodes',
#   'rx_processing_a2/rx_nummodes',
#   'num_detectedmodes',
#   'geolocation/energy_lowestmode_a2',
#   'rx_processing_a5/botloc_amp',
#   'rx_processing_a2/rx_modeenergytobotloc',
#   'rx_processing_a4/sd_sm',
#   'geolocation/elev_lowestmode_a5',
#   'rx_processing_a2/rx_modelocalenergy',
#   'rx_processing_a2/rx_cumulative',
#   'rx_assess/rx_assess_flag',
#   'rx_processing_a5/ancillary/ampval_limit2',
#   'geolocation/lat_lowestreturn_a5',
#   'rx_processing_a5/rx_algrunflag',
#   'rx_processing_a2/ancillary/energy_thresh',
#   'rx_processing_a1/rx_algrunflag',
#   'rx_processing_a4/zcross_amp',
#   'rx_processing_a5/min_detection_threshold',
#   'rx_processing_a2/ancillary/ampval_limit2',
#   'rx_processing_a6/rx_modelocs',
#   'rx_1gaussfit/rx_gamplitude_error',
#   'geolocation/sensitivity_a1',
#   'land_cover_data/leaf_off_doy',
#   'rx_processing_a1/ancillary/enable_select_mode',
#   'rx_processing_a4/ancillary/botlocdist_limit2',
#   'solar_elevation',
#   'land_cover_data/region_class',
#   'geolocation/elevs_allmodes_a2',
#   'rx_processing_a1/rx_modeamps',
#   'rx_processing_a4/lastmodeenergy',
#   'rx_1gaussfit/rx_giters',
#   'rx_processing_a4/rx_modelocalenergy',
#   'rx_processing_a1/search_end',
#   'geolocation/energy_lowestmode_a3',
#   'rx_processing_a1/zcross_localenergy',
#   'rx_processing_a3/back_threshold',
#   'rx_processing_a5/rx_nummodes',
#   'geolocation/elev_lowestreturn_a6',
#   'selected_mode_flag',
#   'elev_highestreturn',
#   'rx_processing_a4/rx_modelocs',
#   'solar_azimuth',
#   'rx_processing_a6/toploc_miss',
#   'rx_processing_a1/ancillary/rx_back_threshold',
#   'geolocation/num_detectedmodes_a2',
#   'rx_processing_a4/min_detection_threshold',
#   'rx_processing_a3/zcross_amp',
#   'selected_algorithm',
#   'geolocation/lon_highestreturn_a3',
#   'rx_processing_a5/ancillary/botlocdist_limit1',
#   'rx_processing_a3/stddev',
#   'geolocation/lon_lowestmode_a1',
#   'rx_processing_a3/min_detection_threshold',
#   'rx_processing_a5/smoothwidth',
#   'rx_1gaussfit/ancillary/rx_constraint_gloc_lower',
#   'rx_processing_a2/rx_algrunflag',
#   'rx_processing_a4/ancillary/rx_searchsize',
#   'rx_assess/sd_corrected',
#   'rx_processing_a6/zcross_amp',
#   'rx_processing_a3/search_end',
#   'quality_flag',
#   'rx_assess/ancillary/rx_ringthresh',
#   'rx_processing_a2/selected_mode',
#   'geolocation/lons_allmodes_a2',
#   'rx_processing_a1/ancillary/amp_thresh',
#   'rx_processing_a5/ancillary/energy_thresh',
#   'rx_processing_a4/toploc_miss',
#   'rx_processing_a3/toploc',
#   'rx_processing_a2/ancillary/botlocdist_limit1',
#   'rx_processing_a2/peak',
#   'rx_processing_a1/lastmodeenergy',
#   'rx_processing_a4/ancillary/rx_smoothing_width_zcross',
#   'geolocation/quality_flag_a4',
#   'rx_processing_a5/zcross0',
#   'rx_processing_a4/mean_sm',
#   'rx_processing_a6/back_threshold',
#   'rx_1gaussfit/ancillary/mpfit_maxiters',
#   'rx_assess/mean_64kadjusted'],
#  'GEDI_L2B': ['rx_processing/rg_eg_flag_a4',
#   'rx_processing/rg_eg_gamma_error_a5',
#   'rx_processing/rg_eg_gamma_error_a1',
#   'rx_processing/rg_error_a3',
#   'rx_processing/rg_eg_amplitude_a2',
#   'geolocation/local_beam_elevation',
#   'ancillary/rg_eg_constraint_center_buffer',
#   'rx_processing/rx_energy_a6',
#   'ancillary/tx_noise_stddev_multiplier',
#   'pgap_theta_z',
#   'rx_processing/rg_eg_center_error_a5',
#   'rx_processing/pgap_theta_a4',
#   'land_cover_data/modis_nonvegetated',
#   'geolocation/longitude_bin0_error',
#   'rx_processing/rg_error_a1',
#   'geolocation/elev_highestreturn',
#   'land_cover_data/landsat_water_persistence',
#   'land_cover_data/leaf_on_doy',
#   'rx_processing/algorithmrun_flag_a5',
#   'geolocation/lon_lowestmode',
#   'rx_processing/rx_energy_a4',
#   'geolocation/digital_elevation_model',
#   'rhov',
#   'rx_processing/rg_a5',
#   'rx_processing/rg_error_a2',
#   'geolocation/longitude_lastbin_error',
#   'rx_processing/rg_a6',
#   'rx_processing/rg_eg_gamma_a1',
#   'l2b_quality_flag',
#   'rx_processing/rg_eg_amplitude_error_a4',
#   'rx_processing/rg_eg_amplitude_a3',
#   'rx_processing/pgap_theta_error_a3',
#   'land_cover_data/leaf_off_flag',
#   'rx_processing/rv_a2',
#   'geolocation/lon_highestreturn',
#   'ancillary/dz',
#   'master_frac',
#   'rx_processing/rg_eg_niter_a1',
#   'l2a_quality_flag',
#   'rx_sample_count',
#   'rx_processing/rg_a4',
#   'pavd_z',
#   'geolocation/lat_highestreturn',
#   'land_cover_data/modis_treecover_sd',
#   'rx_processing/rg_eg_amplitude_error_a2',
#   'rx_processing/rg_eg_center_a2',
#   'rx_processing/rg_eg_center_error_a6',
#   'geolocation/solar_azimuth',
#   'rv',
#   'rx_processing/shot_number',
#   'rx_processing/rg_eg_sigma_a3',
#   'rx_processing/rg_eg_center_a1',
#   'rx_processing/rg_eg_sigma_error_a5',
#   'rx_processing/rg_eg_flag_a6',
#   'rx_processing/rg_eg_flag_a1',
#   'rx_sample_start_index',
#   'rx_processing/pgap_theta_a1',
#   'rx_processing/rg_a2',
#   'omega',
#   'rx_processing/pgap_theta_error_a5',
#   'rx_processing/pgap_theta_error_a4',
#   'land_cover_data/leaf_on_cycle',
#   'rx_processing/rg_eg_niter_a5',
#   'ancillary/rg_eg_mpfit_max_func_evals',
#   'rx_processing/rg_eg_center_error_a4',
#   'rx_processing/rg_eg_gamma_a2',
#   'num_detectedmodes',
#   'rhov_error',
#   'rx_processing/pgap_theta_error_a6',
#   'rx_processing/rg_eg_center_error_a3',
#   'rhog_error',
#   'rx_processing/rg_eg_gamma_a5',
#   'shot_number',
#   'geolocation/latitude_bin0_error',
#   'rx_processing/rg_eg_center_a5',
#   'rx_processing/rg_eg_flag_a3',
#   'fhd_normal',
#   'rx_processing/rg_error_a4',
#   'rx_processing/rg_eg_sigma_error_a2',
#   'rx_processing/algorithmrun_flag_a3',
#   'land_cover_data/modis_treecover',
#   'channel',
#   'rx_processing/rg_eg_gamma_error_a2',
#   'cover',
#   'geolocation/lat_lowestmode',
#   'rx_processing/rg_eg_chisq_a4',
#   'rx_processing/rg_eg_flag_a5',
#   'rx_range_highestreturn',
#   'geolocation/longitude_lastbin',
#   'rx_processing/rg_eg_sigma_a1',
#   'land_cover_data/modis_nonvegetated_sd',
#   'land_cover_data/landsat_treecover',
#   'rx_processing/rg_eg_gamma_error_a4',
#   'rx_processing/rg_eg_amplitude_error_a5',
#   'rx_processing/rg_eg_gamma_a3',
#   'rx_processing/algorithmrun_flag_a2',
#   'geolocation/latitude_lastbin',
#   'rx_processing/rg_error_a5',
#   'geolocation/elevation_bin0_error',
#   'land_cover_data/leaf_off_doy',
#   'rx_processing/rv_a4',
#   'rx_processing/rv_a6',
#   'rx_processing/rx_energy_a1',
#   'rhog',
#   'geolocation/shot_number',
#   'geolocation/solar_elevation',
#   'land_cover_data/region_class',
#   'rx_processing/rv_a3',
#   'rx_processing/rg_eg_amplitude_a4',
#   'rx_processing/rg_eg_gamma_a6',
#   'rx_processing/rx_energy_a5',
#   'rx_processing/algorithmrun_flag_a4',
#   'rx_processing/rg_eg_gamma_a4',
#   'geolocation/latitude_bin0',
#   'selected_mode',
#   'geolocation/elevation_lastbin_error',
#   'rx_processing/rv_a5',
#   'rx_processing/pgap_theta_error_a2',
#   'rx_processing/rv_a1',
#   'rx_processing/rg_eg_niter_a3',
#   'rx_processing/rg_eg_flag_a2',
#   'selected_mode_flag',
#   'land_cover_data/pft_class',
#   'rx_processing/rg_eg_chisq_a1',
#   'rx_processing/rg_eg_center_a3',
#   'rx_processing/rg_eg_center_a6',
#   'ancillary/rg_eg_mpfit_tolerance',
#   'rx_processing/rg_eg_amplitude_a6',
#   'rx_processing/rg_eg_center_error_a1',
#   'algorithmrun_flag',
#   'rx_processing/rg_eg_center_error_a2',
#   'ancillary/rg_eg_mpfit_maxiters',
#   'geolocation/height_lastbin',
#   'rx_processing/pgap_theta_a3',
#   'rx_processing/algorithmrun_flag_a1',
#   'rx_processing/pgap_theta_error_a1',
#   'surface_flag',
#   'geolocation/height_bin0',
#   'rossg',
#   'rx_processing/rx_energy_a3',
#   'pai_z',
#   'beam',
#   'rx_processing/rx_energy_a2',
#   'ancillary/maxheight_cuttoff',
#   'rx_processing/pgap_theta_a6',
#   'rx_processing/rg_eg_chisq_a3',
#   'rx_processing/rg_error_a6',
#   'rx_processing/rg_eg_chisq_a2',
#   'geolocation/local_beam_azimuth',
#   'rh100',
#   'rx_processing/pgap_theta_a5',
#   'rx_processing/rg_eg_gamma_error_a3',
#   'rx_processing/algorithmrun_flag_a6',
#   'rx_processing/rg_eg_sigma_a5',
#   'rx_processing/rg_a1',
#   'rx_processing/rg_eg_niter_a6',
#   'pgap_theta',
#   'rx_processing/rg_eg_center_a4',
#   'rx_processing/rg_eg_amplitude_a1',
#   'geolocation/latitude_lastbin_error',
#   'rx_processing/rg_eg_niter_a2',
#   'rx_processing/rg_eg_amplitude_error_a6',
#   'rx_processing/pgap_theta_a2',
#   'cover_z',
#   'rx_processing/rg_eg_amplitude_error_a1',
#   'rx_processing/rg_eg_sigma_error_a4',
#   'ancillary/l2a_alg_count',
#   'master_int',
#   'pai',
#   'rx_processing/rg_a3',
#   'land_cover_data/urban_proportion',
#   'rx_processing/rg_eg_gamma_error_a6',
#   'rx_processing/rg_eg_sigma_a4',
#   'geolocation/elevation_lastbin',
#   'geolocation/longitude_bin0',
#   'sensitivity',
#   'rx_processing/rg_eg_sigma_a2',
#   'stale_return_flag',
#   'rx_processing/rg_eg_chisq_a6',
#   'land_cover_data/urban_focal_window_size',
#   'rx_processing/rg_eg_niter_a4',
#   'rg',
#   'pgap_theta_error',
#   'rx_processing/rg_eg_sigma_error_a3',
#   'geolocation/degrade_flag',
#   'selected_l2a_algorithm',
#   'rx_processing/rg_eg_sigma_error_a1',
#   'geolocation/elev_lowestmode',
#   'geolocation/delta_time',
#   'rx_processing/rg_eg_amplitude_error_a3',
#   'selected_rg_algorithm',
#   'ancillary/signal_search_buff',
#   'rx_processing/rg_eg_chisq_a5',
#   'rx_processing/rg_eg_amplitude_a5',
#   'rx_processing/rg_eg_sigma_a6',
#   'geolocation/elevation_bin0',
#   'rx_processing/rg_eg_sigma_error_a6']}
# {'GEDI_L1B': ['geolocation/altitude_instrument',
#   'geolocation/local_beam_elevation',
#   'tx_sample_start_index',
#   'nsemean_odd',
#   'ancillary/master_time_epoch',
#   'noise_stddev_corrected',
#   'tx_pulseflag',
#   'geolocation/longitude_bin0_error',
#   'selection_stretchers_x',
#   'nsemean_even',
#   'geolocation/latitude_instrument',
#   'geolocation/digital_elevation_model',
#   'geolocation/longitude_instrument_error',
#   'geolocation/longitude_lastbin_error',
#   'tx_egsigma',
#   'geolocation/neutat_delay_total_bin0',
#   'rx_energy',
#   'master_frac',
#   'rx_sample_count',
#   'rxwaveform',
#   'tx_gloc',
#   'ancillary/mean_samples',
#   'geolocation/longitude_instrument',
#   'tx_eggamma_error',
#   'rx_offset',
#   'tx_egbias_error',
#   'geolocation/bounce_time_offset_lastbin',
#   'all_samples_sum',
#   'geophys_corr/tide_load',
#   'geolocation/solar_azimuth',
#   'geolocation/mean_sea_surface',
#   'geolocation/neutat_delay_total_lastbin',
#   'th_left_used',
#   'rx_sample_start_index',
#   'geophys_corr/tide_ocean',
#   'geophys_corr/tide_ocean_pole',
#   'tx_eggamma',
#   'geophys_corr/tide_pole',
#   'tx_sample_count',
#   'geolocation/surface_type',
#   'geolocation/neutat_delay_derivative_bin0',
#   'geolocation/digital_elevation_model_srtm',
#   'shot_number',
#   'txwaveform',
#   'geolocation/latitude_bin0_error',
#   'geolocation/altitude_instrument_error',
#   'channel',
#   'geolocation/longitude_lastbin',
#   'geolocation/latitude_lastbin',
#   'geolocation/elevation_bin0_error',
#   'geolocation/shot_number',
#   'geolocation/solar_elevation',
#   'geolocation/local_beam_elevation_error',
#   'tx_egamplitude',
#   'geolocation/latitude_bin0',
#   'geolocation/elevation_lastbin_error',
#   'ancillary/smoothing_width',
#   'geolocation/latitude_instrument_error',
#   'tx_egbias',
#   'geolocation/bounce_time_offset_bin0_error',
#   'geolocation/bounce_time_offset_bin0',
#   'rx_open',
#   'beam',
#   'geolocation/local_beam_azimuth',
#   'tx_egflag',
#   'tx_egsigma_error',
#   'geolocation/bounce_time_offset_lastbin_error',
#   'tx_gloc_error',
#   'geophys_corr/geoid',
#   'selection_stretchers_y',
#   'geolocation/latitude_lastbin_error',
#   'master_int',
#   'geolocation/range_bias_correction',
#   'geolocation/elevation_lastbin',
#   'geolocation/longitude_bin0',
#   'stale_return_flag',
#   'geolocation/delta_time',
#   'noise_mean_corrected',
#   'geolocation/local_beam_azimuth_error',
#   'geophys_corr/dynamic_atmosphere_correction',
#   'geophys_corr/delta_time',
#   'tx_egamplitude_error',
#   'geolocation/elevation_bin0',
#   'geolocation/neutat_delay_derivative_lastbin',
#   'geolocation/degrade',
#   'geophys_corr/tide_earth'],
#  'GEDI_L2A': ['rx_processing_a4/ancillary/rx_subbin_resolution',
#   'rx_processing_a6/ancillary/rx_use_fixed_thresholds',
#   'rx_processing_a1/rx_iwaveamps',
#   'rx_processing_a1/selected_mode_flag',
#   'rx_processing_a2/sd_sm',
#   'geolocation/elev_highestreturn_a2',
#   'rx_processing_a2/zcross0',
#   'geolocation/rh_a6',
#   'rx_processing_a2/ancillary/preprocessor_threshold',
#   'rx_processing_a4/ancillary/rx_max_mode_count',
#   'geolocation/elevs_allmodes_a3',
#   'rx_processing_a1/ancillary/rx_smoothing_width_zcross',
#   'rx_processing_a6/sd_sm',
#   'rx_processing_a3/rx_cumulative',
#   'geolocation/quality_flag_a6',
#   'lat_highestreturn',
#   'rx_1gaussfit/ancillary/rx_constraint_gloc_upper',
#   'rx_assess/ancillary/rx_pulsethresh',
#   'rx_processing_a3/selected_mode',
#   'rx_processing_a5/ancillary/enable_select_mode',
#   'geolocation/elev_highestreturn_a1',
#   'rx_processing_a1/toploc',
#   'rx_1gaussfit/ancillary/rx_estimate_bias',
#   'rx_processing_a1/search_start',
#   'rx_processing_a6/ancillary/rx_subbin_resolution',
#   'rx_processing_a6/zcross_localenergy',
#   'geolocation/energy_lowestmode_a6',
#   'master_frac',
#   'rx_processing_a4/ancillary/ampval_limit3',
#   'rx_processing_a6/selected_mode',
#   'geolocation/lat_highestreturn_a4',
#   'rx_processing_a1/ancillary/botlocdist_limit2',
#   'rx_processing_a3/min_detection_energy',
#   'rx_processing_a6/peak',
#   'rx_processing_a5/rx_modelocalslope',
#   'rx_processing_a6/ancillary/cumulative_energy_thresh',
#   'geolocation/lon_lowestmode_a6',
#   'rx_processing_a6/ancillary/pulse_sep_thresh',
#   'rx_processing_a5/lastmodeenergy',
#   'rx_1gaussfit/ancillary/rx_constraint_gamplitude_upper',
#   'geolocation/elevs_allmodes_a5',
#   'rx_assess/rx_energy',
#   'rx_processing_a6/rx_cumulative',
#   'delta_time',
#   'rx_processing_a2/rx_modelocs',
#   'rx_processing_a6/ancillary/rx_searchsize',
#   'elev_lowestmode',
#   'rx_processing_a3/selected_mode_flag',
#   'rx_processing_a5/pk_sm',
#   'rx_processing_a2/ancillary/rx_subbin_resolution',
#   'rx_processing_a5/ancillary/botlocdist_limit2',
#   'geolocation/lats_allmodes_a3',
#   'geolocation/lat_highestreturn_a5',
#   'geolocation/lon_lowestreturn_a6',
#   'rx_processing_a1/energy_sm',
#   'rx_processing_a5/stddev',
#   'rx_processing_a2/ancillary/rx_use_fixed_thresholds',
#   'geolocation/lon_lowestmode_a4',
#   'rx_processing_a3/ancillary/rx_back_threshold',
#   'geolocation/num_detectedmodes_a1',
#   'rx_processing_a3/ancillary/botlocdist_limit3',
#   'rx_processing_a1/ancillary/rx_searchsize',
#   'rx_processing_a2/toploc_miss',
#   'geolocation/lat_highestreturn_a6',
#   'rx_processing_a3/ancillary/botlocdist_limit1',
#   'rx_processing_a5/rx_modelocs',
#   'rx_processing_a6/ancillary/botlocdist_limit3',
#   'geolocation/lon_lowestreturn_a1',
#   'geolocation/rh_a1',
#   'land_cover_data/modis_nonvegetated_sd',
#   'rx_processing_a1/rx_modeenergytobotloc',
#   'rx_processing_a3/ancillary/pulse_sep_thresh',
#   'rx_processing_a2/toploc',
#   'rx_processing_a4/ancillary/rx_use_fixed_thresholds',
#   'geolocation/sensitivity_a2',
#   'rx_processing_a1/ancillary/energy_thresh',
#   'rx_processing_a5/rx_modeenergytobotloc',
#   'geolocation/lon_highestreturn_a6',
#   'rx_processing_a1/min_detection_threshold',
#   'rx_processing_a1/ancillary/rx_sentinel_location',
#   'rx_processing_a1/rx_nummodes',
#   'rx_processing_a6/zcross',
#   'rx_processing_a4/rx_modeenergytobotloc',
#   'selected_mode',
#   'rx_processing_a5/botloc',
#   'latitude_bin0_error',
#   'rx_processing_a3/search_start',
#   'rx_processing_a5/rx_modelocalenergyabovemean',
#   'rx_1gaussfit/ancillary/mpfit_tolerance',
#   'geolocation/lons_allmodes_a4',
#   'rx_1gaussfit/rx_gwidth',
#   'land_cover_data/pft_class',
#   'rx_processing_a4/rx_cumulative',
#   'geolocation/lat_lowestmode_a5',
#   'rx_processing_a3/rx_algrunflag',
#   'rx_processing_a3/ancillary/rx_smoothing_width_zcross',
#   'rx_processing_a4/toploc',
#   'rx_processing_a6/stddev',
#   'rx_processing_a1/ancillary/ampval_limit2',
#   'rx_assess/mean',
#   'rx_processing_a4/botloc_amp',
#   'geolocation/elev_lowestmode_a2',
#   'rx_processing_a1/ancillary/preprocessor_threshold',
#   'rx_processing_a5/smoothwidth_zcross',
#   'rx_processing_a1/zcross',
#   'rx_processing_a1/back_threshold',
#   'rx_processing_a6/smoothwidth',
#   'geolocation/lon_lowestmode_a2',
#   'rx_processing_a4/ancillary/rx_sentinel_location',
#   'geolocation/lat_lowestmode_a3',
#   'rx_processing_a1/ancillary/rx_front_threshold',
#   'rx_processing_a2/smoothwidth_zcross',
#   'rx_processing_a6/ancillary/ampval_limit3',
#   'rx_processing_a2/search_end',
#   'rx_processing_a4/ancillary/rx_smoothing_width_locs',
#   'rx_processing_a3/zcross',
#   'rx_processing_a4/rx_modelocalenergyabovemean',
#   'rx_processing_a2/botloc',
#   'ancillary/l2a_alg_count',
#   'rx_processing_a6/energy_sm',
#   'rx_processing_a2/front_threshold',
#   'land_cover_data/urban_proportion',
#   'rx_processing_a6/search_start',
#   'rx_processing_a2/ancillary/rx_searchsize',
#   'sensitivity',
#   'rx_processing_a5/ancillary/rx_front_threshold',
#   'geolocation/num_detectedmodes_a4',
#   'geolocation/sensitivity_a6',
#   'geolocation/lats_allmodes_a5',
#   'geolocation/lon_lowestmode_a3',
#   'rx_processing_a6/ancillary/rx_front_threshold',
#   'rx_processing_a3/botloc_amp',
#   'rx_processing_a4/back_threshold',
#   'rx_processing_a3/rx_modelocalenergy',
#   'geolocation/quality_flag_a5',
#   'rx_processing_a3/ancillary/rx_use_fixed_thresholds',
#   'rx_processing_a6/rx_modewidths',
#   'rx_processing_a2/min_detection_threshold',
#   'geolocation/elev_highestreturn_a3',
#   'geolocation/lon_highestreturn_a2',
#   'rx_processing_a6/zcross0',
#   'rx_processing_a1/rx_modelocalenergy',
#   'rx_processing_a4/rx_iwaveamps',
#   'rx_processing_a3/ancillary/rx_subbin_resolution',
#   'rx_processing_a3/mean',
#   'lon_highestreturn',
#   'rx_processing_a3/smoothwidth_zcross',
#   'rx_processing_a4/peak',
#   'geolocation/num_detectedmodes_a6',
#   'rx_processing_a2/zcross',
#   'rx_processing_a6/ancillary/preprocessor_threshold',
#   'rx_processing_a3/mean_sm',
#   'rx_processing_a2/rx_modewidths',
#   'digital_elevation_model',
#   'land_cover_data/landsat_water_persistence',
#   'geolocation/lat_lowestmode_a4',
#   'rx_processing_a5/selected_mode',
#   'rx_1gaussfit/ancillary/rx_constraint_gamplitude_lower',
#   'rx_1gaussfit/rx_gflag',
#   'rx_processing_a6/botloc',
#   'rx_processing_a5/rx_iwaveamps',
#   'rx_processing_a4/ancillary/cumulative_energy_minimum',
#   'rx_processing_a4/ancillary/pulse_sep_thresh',
#   'rx_assess/quality_flag',
#   'rx_processing_a4/rx_modewidths',
#   'rx_processing_a3/ancillary/botlocdist_limit2',
#   'rx_processing_a3/ancillary/enable_select_mode',
#   'rx_processing_a6/search_end',
#   'rx_processing_a6/rx_modelocalenergyabovemean',
#   'geolocation/elev_highestreturn_a4',
#   'rx_processing_a2/ancillary/cumulative_energy_minimum',
#   'rx_processing_a5/search_end',
#   'geolocation/lats_allmodes_a2',
#   'geolocation/quality_flag_a2',
#   'rx_1gaussfit/ancillary/rx_constraint_gwidth_lower',
#   'rx_processing_a6/rx_nummodes',
#   'rx_processing_a5/rx_modelocalenergy',
#   'rx_processing_a2/ancillary/rx_sentinel_location',
#   'rx_processing_a3/zcross0',
#   'rx_processing_a3/sd_sm',
#   'land_cover_data/leaf_on_cycle',
#   'rx_processing_a3/front_threshold',
#   'rx_1gaussfit/ancillary/mpfit_max_func_evals',
#   'rx_processing_a3/ancillary/ampval_limit3',
#   'rx_processing_a1/zcross0',
#   'rx_processing_a5/ancillary/rx_sentinel_location',
#   'rx_assess/rx_clipbin0',
#   'rx_processing_a1/botloc',
#   'shot_number',
#   'rx_processing_a5/sd_sm',
#   'rx_processing_a6/botloc_amp',
#   'geolocation/elev_highestreturn_a6',
#   'digital_elevation_model_srtm',
#   'rx_1gaussfit/ancillary/rx_mean_noise_level',
#   'rx_processing_a2/rx_iwaveamps',
#   'rx_processing_a6/ancillary/amp_thresh',
#   'rx_processing_a6/ancillary/ampval_limit2',
#   'channel',
#   'rx_processing_a2/ancillary/enable_select_mode',
#   'rx_processing_a3/pk_sm',
#   'rx_assess/rx_maxamp',
#   'rx_assess/ancillary/rx_ampbounds_ul',
#   'rx_processing_a6/rx_modelocalenergy',
#   'land_cover_data/landsat_treecover',
#   'rx_assess/rx_clipbin_count',
#   'rx_processing_a6/lastmodeenergy',
#   'geolocation/latitude_1gfit',
#   'geolocation/elevation_1gfit',
#   'rx_processing_a3/ancillary/rx_smoothing_width_locs',
#   'rx_processing_a1/smoothwidth',
#   'rx_processing_a6/rx_modeamps',
#   'rx_processing_a2/ancillary/cumulative_energy_thresh',
#   'rx_processing_a1/botloc_amp',
#   'rx_processing_a3/energy_sm',
#   'rx_processing_a2/search_start',
#   'rx_processing_a4/ancillary/botlocdist_limit1',
#   'rx_processing_a3/smoothwidth',
#   'rx_processing_a6/min_detection_threshold',
#   'geolocation/lat_lowestmode_a6',
#   'rh',
#   'rx_processing_a4/ancillary/enable_select_mode',
#   'rx_processing_a4/mean',
#   'rx_processing_a4/zcross_localenergy',
#   'geolocation/elev_highestreturn_a5',
#   'rx_processing_a1/selected_mode',
#   'rx_processing_a4/ancillary/ampval_limit2',
#   'geolocation/lon_highestreturn_a5',
#   'rx_processing_a2/rx_modelocalslope',
#   'rx_processing_a5/selected_mode_flag',
#   'geolocation/lon_highestreturn_a4',
#   'mean_sea_surface',
#   'geolocation/lat_lowestreturn_a2',
#   'surface_flag',
#   'rx_processing_a5/ancillary/rx_back_threshold',
#   'rx_processing_a5/peak',
#   'rx_processing_a2/back_threshold',
#   'geolocation/sensitivity_a4',
#   'geolocation/lat_lowestreturn_a3',
#   'rx_processing_a3/zcross_localenergy',
#   'rx_processing_a2/min_detection_energy',
#   'geolocation/energy_lowestmode_a5',
#   'rx_processing_a3/ancillary/rx_front_threshold',
#   'rx_processing_a4/energy_sm',
#   'rx_processing_a5/ancillary/botlocdist_limit3',
#   'geolocation/stale_return_flag',
#   'geolocation/lats_allmodes_a4',
#   'rx_processing_a3/ancillary/amp_thresh',
#   'rx_processing_a5/zcross_localenergy',
#   'rx_processing_a4/selected_mode_flag',
#   'geolocation/lat_highestreturn_a1',
#   'master_int',
#   'rx_processing_a2/zcross_amp',
#   'geolocation/lat_highestreturn_a3',
#   'rx_assess/ancillary/rx_ampbounds_ll',
#   'rx_processing_a3/ancillary/preprocessor_threshold',
#   'rx_processing_a6/ancillary/rx_max_mode_count',
#   'rx_processing_a5/ancillary/amp_thresh',
#   'rx_1gaussfit/rx_gloc_error',
#   'rx_processing_a2/ancillary/rx_max_mode_count',
#   'geolocation/lat_highestreturn_a2',
#   'land_cover_data/urban_focal_window_size',
#   'rx_processing_a2/smoothwidth',
#   'rx_processing_a3/ancillary/cumulative_energy_minimum',
#   'rx_1gaussfit/ancillary/rx_smoothwidth',
#   'rx_processing_a4/zcross0',
#   'rx_processing_a3/rx_modelocalslope',
#   'rx_processing_a6/ancillary/rx_back_threshold',
#   'geolocation/lats_allmodes_a1',
#   'geolocation/lons_allmodes_a1',
#   'geolocation/lon_lowestreturn_a3',
#   'rx_processing_a1/zcross_amp',
#   'lat_lowestmode',
#   'geolocation/lat_lowestreturn_a4',
#   'rx_processing_a5/front_threshold',
#   'geolocation/lon_highestreturn_a1',
#   'rx_processing_a2/ancillary/pulse_sep_thresh',
#   'rx_processing_a1/ancillary/botlocdist_limit1',
#   'geolocation/sensitivity_a3',
#   'rx_assess/rx_maxpeakloc',
#   'rx_processing_a5/ancillary/preprocessor_threshold',
#   'geolocation/rh_a5',
#   'rx_1gaussfit/ancillary/rx_constraint_gwidth_upper',
#   'geolocation/elev_lowestmode_a4',
#   'rx_processing_a1/mean',
#   'geolocation/lat_lowestmode_a1',
#   'land_cover_data/leaf_on_doy',
#   'geolocation/lon_lowestreturn_a5',
#   'longitude_bin0_error',
#   'geolocation/elev_lowestreturn_a1',
#   'rx_processing_a2/ancillary/botlocdist_limit2',
#   'geolocation/energy_lowestmode_a1',
#   'geolocation/elev_lowestmode_a6',
#   'rx_processing_a1/ancillary/botlocdist_limit3',
#   'rx_processing_a5/min_detection_energy',
#   'rx_processing_a6/min_detection_energy',
#   'rx_processing_a4/ancillary/amp_thresh',
#   'rx_1gaussfit/rx_gloc',
#   'rx_processing_a6/mean_sm',
#   'rx_assess/ancillary/rx_clipamp',
#   'rx_processing_a1/rx_modelocalenergyabovemean',
#   'rx_processing_a3/peak',
#   'rx_processing_a1/rx_modewidths',
#   'geolocation/num_detectedmodes_a3',
#   'geolocation/elev_lowestreturn_a4',
#   'rx_processing_a3/rx_modewidths',
#   'rx_processing_a4/ancillary/cumulative_energy_thresh',
#   'geolocation/lat_lowestreturn_a1',
#   'rx_processing_a1/rx_modelocs',
#   'rx_processing_a4/smoothwidth_zcross',
#   'rx_processing_a6/selected_mode_flag',
#   'rx_processing_a1/ancillary/rx_smoothing_width_locs',
#   'rx_processing_a4/rx_algrunflag',
#   'rx_1gaussfit/rx_gamplitude',
#   'rx_processing_a1/ancillary/rx_subbin_resolution',
#   'rx_processing_a6/rx_modeenergytobotloc',
#   'rx_processing_a2/ancillary/ampval_limit3',
#   'rx_processing_a6/mean',
#   'geolocation/elevs_allmodes_a6',
#   'rx_1gaussfit/rx_gchisq',
#   'geolocation/elev_lowestmode_a3',
#   'geolocation/energy_lowestmode_a4',
#   'rx_processing_a3/rx_modelocalenergyabovemean',
#   'geolocation/elev_lowestreturn_a5',
#   'rx_processing_a5/ancillary/rx_smoothing_width_zcross',
#   'rx_processing_a2/ancillary/rx_smoothing_width_locs',
#   'rx_processing_a1/pk_sm',
#   'geolocation/lons_allmodes_a3',
#   'geolocation/num_detectedmodes_a5',
#   'rx_processing_a2/energy_sm',
#   'land_cover_data/modis_treecover',
#   'rx_1gaussfit/rx_gbias_error',
#   'rx_processing_a4/botloc',
#   'rx_processing_a1/ancillary/cumulative_energy_thresh',
#   'geolocation/lat_lowestmode_a2',
#   'geolocation/rh_a2',
#   'rx_processing_a2/ancillary/amp_thresh',
#   'rx_processing_a2/ancillary/botlocdist_limit3',
#   'rx_processing_a2/lastmodeenergy',
#   'rx_processing_a3/ancillary/energy_thresh',
#   'rx_processing_a1/ancillary/rx_max_mode_count',
#   'geolocation/elevs_allmodes_a1',
#   'rx_processing_a6/ancillary/rx_smoothing_width_zcross',
#   'rx_processing_a4/stddev',
#   'rx_processing_a5/toploc',
#   'rx_processing_a5/ancillary/rx_use_fixed_thresholds',
#   'rx_assess/ancillary/smoothing_width_locs',
#   'geolocation/longitude_1gfit',
#   'geolocation/lons_allmodes_a6',
#   'rx_1gaussfit/rx_gwidth_error',
#   'rx_processing_a5/ancillary/ampval_limit3',
#   'rx_processing_a5/toploc_miss',
#   'rx_processing_a1/min_detection_energy',
#   'rx_processing_a3/lastmodeenergy',
#   'rx_processing_a3/rx_iwaveamps',
#   'rx_processing_a3/ancillary/ampval_limit2',
#   'geolocation/sensitivity_a5',
#   'rx_processing_a4/selected_mode',
#   'rx_processing_a4/search_end',
#   'rx_processing_a2/ancillary/rx_front_threshold',
#   'rx_processing_a4/search_start',
#   'geolocation/elev_lowestmode_a1',
#   'rx_processing_a5/rx_modeamps',
#   'rx_processing_a6/ancillary/energy_thresh',
#   'rx_processing_a2/ancillary/rx_smoothing_width_zcross',
#   'rx_processing_a6/ancillary/botlocdist_limit2',
#   'rx_processing_a4/ancillary/botlocdist_limit3',
#   'rx_1gaussfit/rx_gbias',
#   'rx_processing_a5/mean_sm',
#   'rx_processing_a6/ancillary/rx_smoothing_width_locs',
#   'rx_processing_a1/ancillary/rx_use_fixed_thresholds',
#   'rx_processing_a4/rx_modelocalslope',
#   'beam',
#   'rx_processing_a6/front_threshold',
#   'rx_processing_a3/toploc_miss',
#   'rx_processing_a5/rx_modewidths',
#   'rx_processing_a3/ancillary/rx_searchsize',
#   'rx_processing_a4/ancillary/rx_back_threshold',
#   'rx_processing_a1/ancillary/ampval_limit3',
#   'rx_processing_a5/ancillary/pulse_sep_thresh',
#   'rx_processing_a4/ancillary/preprocessor_threshold',
#   'rx_processing_a2/zcross_localenergy',
#   'rx_processing_a4/rx_modeamps',
#   'rx_processing_a2/selected_mode_flag',
#   'rx_processing_a4/ancillary/energy_thresh',
#   'rx_processing_a2/rx_modelocalenergyabovemean',
#   'geolocation/elev_lowestreturn_a3',
#   'rx_processing_a6/rx_algrunflag',
#   'rx_processing_a3/ancillary/rx_sentinel_location',
#   'rx_processing_a5/ancillary/rx_subbin_resolution',
#   'rx_processing_a6/pk_sm',
#   'rx_processing_a4/pk_sm',
#   'geolocation/rh_a3',
#   'rx_processing_a4/min_detection_energy',
#   'rx_processing_a4/zcross',
#   'rx_processing_a4/smoothwidth',
#   'rx_processing_a2/ancillary/rx_back_threshold',
#   'rx_processing_a3/rx_modeamps',
#   'rx_processing_a5/energy_sm',
#   'lon_lowestmode',
#   'rx_processing_a6/rx_iwaveamps',
#   'rx_processing_a5/zcross_amp',
#   'rx_processing_a1/ancillary/pulse_sep_thresh',
#   'rx_processing_a6/ancillary/rx_sentinel_location',
#   'rx_processing_a3/ancillary/cumulative_energy_thresh',
#   'rx_processing_a1/smoothwidth_zcross',
#   'degrade_flag',
#   'geolocation/lons_allmodes_a5',
#   'rx_processing_a5/rx_cumulative',
#   'rx_processing_a4/ancillary/rx_front_threshold',
#   'rx_processing_a1/front_threshold',
#   'geolocation/quality_flag_a3',
#   'rx_processing_a1/stddev',
#   'rx_processing_a3/rx_modelocs',
#   'rx_processing_a2/stddev',
#   'rx_processing_a6/smoothwidth_zcross',
#   'rx_processing_a3/botloc',
#   'rx_processing_a5/ancillary/cumulative_energy_minimum',
#   'rx_processing_a3/rx_nummodes',
#   'rx_processing_a2/mean_sm',
#   'rx_processing_a1/rx_modelocalslope',
#   'geolocation/lats_allmodes_a6',
#   'rx_processing_a1/sd_sm',
#   'geolocation/lon_lowestreturn_a2',
#   'geolocation/lon_lowestreturn_a4',
#   'rx_processing_a2/mean',
#   'rx_processing_a6/toploc',
#   'elevation_bin0_error',
#   'rx_processing_a5/ancillary/rx_max_mode_count',
#   'land_cover_data/modis_nonvegetated',
#   'rx_processing_a1/mean_sm',
#   'geolocation/lat_lowestreturn_a6',
#   'rx_processing_a5/zcross',
#   'rx_processing_a4/front_threshold',
#   'rx_processing_a1/toploc_miss',
#   'rx_processing_a1/ancillary/cumulative_energy_minimum',
#   'rx_processing_a1/rx_cumulative',
#   'elevation_bias_flag',
#   'rx_processing_a2/rx_modeamps',
#   'rx_processing_a6/ancillary/botlocdist_limit1',
#   'geolocation/rh_a4',
#   'rx_processing_a5/search_start',
#   'rx_processing_a1/peak',
#   'rx_processing_a5/ancillary/cumulative_energy_thresh',
#   'energy_total',
#   'land_cover_data/leaf_off_flag',
#   'rx_processing_a5/mean',
#   'rx_processing_a6/ancillary/enable_select_mode',
#   'rx_processing_a6/rx_modelocalslope',
#   'rx_processing_a5/ancillary/rx_smoothing_width_locs',
#   'rx_processing_a5/back_threshold',
#   'rx_processing_a2/botloc_amp',
#   'land_cover_data/modis_treecover_sd',
#   'geolocation/elevs_allmodes_a4',
#   'geolocation/lon_lowestmode_a5',
#   'geolocation/quality_flag_a1',
#   'rx_processing_a6/ancillary/cumulative_energy_minimum',
#   'rx_processing_a2/pk_sm',
#   'rx_processing_a5/ancillary/rx_searchsize',
#   'rx_processing_a3/rx_modeenergytobotloc',
#   'rx_assess/ocean_calibration_shot_flag',
#   'rx_processing_a3/ancillary/rx_max_mode_count',
#   'geolocation/elev_lowestreturn_a2',
#   'rx_processing_a4/rx_nummodes',
#   'rx_processing_a2/rx_nummodes',
#   'num_detectedmodes',
#   'geolocation/energy_lowestmode_a2',
#   'rx_processing_a5/botloc_amp',
#   'rx_processing_a2/rx_modeenergytobotloc',
#   'rx_processing_a4/sd_sm',
#   'geolocation/elev_lowestmode_a5',
#   'rx_processing_a2/rx_modelocalenergy',
#   'rx_processing_a2/rx_cumulative',
#   'rx_assess/rx_assess_flag',
#   'rx_processing_a5/ancillary/ampval_limit2',
#   'geolocation/lat_lowestreturn_a5',
#   'rx_processing_a5/rx_algrunflag',
#   'rx_processing_a2/ancillary/energy_thresh',
#   'rx_processing_a1/rx_algrunflag',
#   'rx_processing_a4/zcross_amp',
#   'rx_processing_a5/min_detection_threshold',
#   'rx_processing_a2/ancillary/ampval_limit2',
#   'rx_processing_a6/rx_modelocs',
#   'rx_1gaussfit/rx_gamplitude_error',
#   'geolocation/sensitivity_a1',
#   'land_cover_data/leaf_off_doy',
#   'rx_processing_a1/ancillary/enable_select_mode',
#   'rx_processing_a4/ancillary/botlocdist_limit2',
#   'solar_elevation',
#   'land_cover_data/region_class',
#   'geolocation/elevs_allmodes_a2',
#   'rx_processing_a1/rx_modeamps',
#   'rx_processing_a4/lastmodeenergy',
#   'rx_1gaussfit/rx_giters',
#   'rx_processing_a4/rx_modelocalenergy',
#   'rx_processing_a1/search_end',
#   'geolocation/energy_lowestmode_a3',
#   'rx_processing_a1/zcross_localenergy',
#   'rx_processing_a3/back_threshold',
#   'rx_processing_a5/rx_nummodes',
#   'geolocation/elev_lowestreturn_a6',
#   'selected_mode_flag',
#   'elev_highestreturn',
#   'rx_processing_a4/rx_modelocs',
#   'solar_azimuth',
#   'rx_processing_a6/toploc_miss',
#   'rx_processing_a1/ancillary/rx_back_threshold',
#   'geolocation/num_detectedmodes_a2',
#   'rx_processing_a4/min_detection_threshold',
#   'rx_processing_a3/zcross_amp',
#   'selected_algorithm',
#   'geolocation/lon_highestreturn_a3',
#   'rx_processing_a5/ancillary/botlocdist_limit1',
#   'rx_processing_a3/stddev',
#   'geolocation/lon_lowestmode_a1',
#   'rx_processing_a3/min_detection_threshold',
#   'rx_processing_a5/smoothwidth',
#   'rx_1gaussfit/ancillary/rx_constraint_gloc_lower',
#   'rx_processing_a2/rx_algrunflag',
#   'rx_processing_a4/ancillary/rx_searchsize',
#   'rx_assess/sd_corrected',
#   'rx_processing_a6/zcross_amp',
#   'rx_processing_a3/search_end',
#   'quality_flag',
#   'rx_assess/ancillary/rx_ringthresh',
#   'rx_processing_a2/selected_mode',
#   'geolocation/lons_allmodes_a2',
#   'rx_processing_a1/ancillary/amp_thresh',
#   'rx_processing_a5/ancillary/energy_thresh',
#   'rx_processing_a4/toploc_miss',
#   'rx_processing_a3/toploc',
#   'rx_processing_a2/ancillary/botlocdist_limit1',
#   'rx_processing_a2/peak',
#   'rx_processing_a1/lastmodeenergy',
#   'rx_processing_a4/ancillary/rx_smoothing_width_zcross',
#   'geolocation/quality_flag_a4',
#   'rx_processing_a5/zcross0',
#   'rx_processing_a4/mean_sm',
#   'rx_processing_a6/back_threshold',
#   'rx_1gaussfit/ancillary/mpfit_maxiters',
#   'rx_assess/mean_64kadjusted'],
#  'GEDI_L2B': ['rx_processing/rg_eg_flag_a4',
#   'rx_processing/rg_eg_gamma_error_a5',
#   'rx_processing/rg_eg_gamma_error_a1',
#   'rx_processing/rg_error_a3',
#   'rx_processing/rg_eg_amplitude_a2',
#   'geolocation/local_beam_elevation',
#   'ancillary/rg_eg_constraint_center_buffer',
#   'rx_processing/rx_energy_a6',
#   'ancillary/tx_noise_stddev_multiplier',
#   'pgap_theta_z',
#   'rx_processing/rg_eg_center_error_a5',
#   'rx_processing/pgap_theta_a4',
#   'land_cover_data/modis_nonvegetated',
#   'geolocation/longitude_bin0_error',
#   'rx_processing/rg_error_a1',
#   'geolocation/elev_highestreturn',
#   'land_cover_data/landsat_water_persistence',
#   'land_cover_data/leaf_on_doy',
#   'rx_processing/algorithmrun_flag_a5',
#   'geolocation/lon_lowestmode',
#   'rx_processing/rx_energy_a4',
#   'geolocation/digital_elevation_model',
#   'rhov',
#   'rx_processing/rg_a5',
#   'rx_processing/rg_error_a2',
#   'geolocation/longitude_lastbin_error',
#   'rx_processing/rg_a6',
#   'rx_processing/rg_eg_gamma_a1',
#   'l2b_quality_flag',
#   'rx_processing/rg_eg_amplitude_error_a4',
#   'rx_processing/rg_eg_amplitude_a3',
#   'rx_processing/pgap_theta_error_a3',
#   'land_cover_data/leaf_off_flag',
#   'rx_processing/rv_a2',
#   'geolocation/lon_highestreturn',
#   'ancillary/dz',
#   'master_frac',
#   'rx_processing/rg_eg_niter_a1',
#   'l2a_quality_flag',
#   'rx_sample_count',
#   'rx_processing/rg_a4',
#   'pavd_z',
#   'geolocation/lat_highestreturn',
#   'land_cover_data/modis_treecover_sd',
#   'rx_processing/rg_eg_amplitude_error_a2',
#   'rx_processing/rg_eg_center_a2',
#   'rx_processing/rg_eg_center_error_a6',
#   'geolocation/solar_azimuth',
#   'rv',
#   'rx_processing/shot_number',
#   'rx_processing/rg_eg_sigma_a3',
#   'rx_processing/rg_eg_center_a1',
#   'rx_processing/rg_eg_sigma_error_a5',
#   'rx_processing/rg_eg_flag_a6',
#   'rx_processing/rg_eg_flag_a1',
#   'rx_sample_start_index',
#   'rx_processing/pgap_theta_a1',
#   'rx_processing/rg_a2',
#   'omega',
#   'rx_processing/pgap_theta_error_a5',
#   'rx_processing/pgap_theta_error_a4',
#   'land_cover_data/leaf_on_cycle',
#   'rx_processing/rg_eg_niter_a5',
#   'ancillary/rg_eg_mpfit_max_func_evals',
#   'rx_processing/rg_eg_center_error_a4',
#   'rx_processing/rg_eg_gamma_a2',
#   'num_detectedmodes',
#   'rhov_error',
#   'rx_processing/pgap_theta_error_a6',
#   'rx_processing/rg_eg_center_error_a3',
#   'rhog_error',
#   'rx_processing/rg_eg_gamma_a5',
#   'shot_number',
#   'geolocation/latitude_bin0_error',
#   'rx_processing/rg_eg_center_a5',
#   'rx_processing/rg_eg_flag_a3',
#   'fhd_normal',
#   'rx_processing/rg_error_a4',
#   'rx_processing/rg_eg_sigma_error_a2',
#   'rx_processing/algorithmrun_flag_a3',
#   'land_cover_data/modis_treecover',
#   'channel',
#   'rx_processing/rg_eg_gamma_error_a2',
#   'cover',
#   'geolocation/lat_lowestmode',
#   'rx_processing/rg_eg_chisq_a4',
#   'rx_processing/rg_eg_flag_a5',
#   'rx_range_highestreturn',
#   'geolocation/longitude_lastbin',
#   'rx_processing/rg_eg_sigma_a1',
#   'land_cover_data/modis_nonvegetated_sd',
#   'land_cover_data/landsat_treecover',
#   'rx_processing/rg_eg_gamma_error_a4',
#   'rx_processing/rg_eg_amplitude_error_a5',
#   'rx_processing/rg_eg_gamma_a3',
#   'rx_processing/algorithmrun_flag_a2',
#   'geolocation/latitude_lastbin',
#   'rx_processing/rg_error_a5',
#   'geolocation/elevation_bin0_error',
#   'land_cover_data/leaf_off_doy',
#   'rx_processing/rv_a4',
#   'rx_processing/rv_a6',
#   'rx_processing/rx_energy_a1',
#   'rhog',
#   'geolocation/shot_number',
#   'geolocation/solar_elevation',
#   'land_cover_data/region_class',
#   'rx_processing/rv_a3',
#   'rx_processing/rg_eg_amplitude_a4',
#   'rx_processing/rg_eg_gamma_a6',
#   'rx_processing/rx_energy_a5',
#   'rx_processing/algorithmrun_flag_a4',
#   'rx_processing/rg_eg_gamma_a4',
#   'geolocation/latitude_bin0',
#   'selected_mode',
#   'geolocation/elevation_lastbin_error',
#   'rx_processing/rv_a5',
#   'rx_processing/pgap_theta_error_a2',
#   'rx_processing/rv_a1',
#   'rx_processing/rg_eg_niter_a3',
#   'rx_processing/rg_eg_flag_a2',
#   'selected_mode_flag',
#   'land_cover_data/pft_class',
#   'rx_processing/rg_eg_chisq_a1',
#   'rx_processing/rg_eg_center_a3',
#   'rx_processing/rg_eg_center_a6',
#   'ancillary/rg_eg_mpfit_tolerance',
#   'rx_processing/rg_eg_amplitude_a6',
#   'rx_processing/rg_eg_center_error_a1',
#   'algorithmrun_flag',
#   'rx_processing/rg_eg_center_error_a2',
#   'ancillary/rg_eg_mpfit_maxiters',
#   'geolocation/height_lastbin',
#   'rx_processing/pgap_theta_a3',
#   'rx_processing/algorithmrun_flag_a1',
#   'rx_processing/pgap_theta_error_a1',
#   'surface_flag',
#   'geolocation/height_bin0',
#   'rossg',
#   'rx_processing/rx_energy_a3',
#   'pai_z',
#   'beam',
#   'rx_processing/rx_energy_a2',
#   'ancillary/maxheight_cuttoff',
#   'rx_processing/pgap_theta_a6',
#   'rx_processing/rg_eg_chisq_a3',
#   'rx_processing/rg_error_a6',
#   'rx_processing/rg_eg_chisq_a2',
#   'geolocation/local_beam_azimuth',
#   'rh100',
#   'rx_processing/pgap_theta_a5',
#   'rx_processing/rg_eg_gamma_error_a3',
#   'rx_processing/algorithmrun_flag_a6',
#   'rx_processing/rg_eg_sigma_a5',
#   'rx_processing/rg_a1',
#   'rx_processing/rg_eg_niter_a6',
#   'pgap_theta',
#   'rx_processing/rg_eg_center_a4',
#   'rx_processing/rg_eg_amplitude_a1',
#   'geolocation/latitude_lastbin_error',
#   'rx_processing/rg_eg_niter_a2',
#   'rx_processing/rg_eg_amplitude_error_a6',
#   'rx_processing/pgap_theta_a2',
#   'cover_z',
#   'rx_processing/rg_eg_amplitude_error_a1',
#   'rx_processing/rg_eg_sigma_error_a4',
#   'ancillary/l2a_alg_count',
#   'master_int',
#   'pai',
#   'rx_processing/rg_a3',
#   'land_cover_data/urban_proportion',
#   'rx_processing/rg_eg_gamma_error_a6',
#   'rx_processing/rg_eg_sigma_a4',
#   'geolocation/elevation_lastbin',
#   'geolocation/longitude_bin0',
#   'sensitivity',
#   'rx_processing/rg_eg_sigma_a2',
#   'stale_return_flag',
#   'rx_processing/rg_eg_chisq_a6',
#   'land_cover_data/urban_focal_window_size',
#   'rx_processing/rg_eg_niter_a4',
#   'rg',
#   'pgap_theta_error',
#   'rx_processing/rg_eg_sigma_error_a3',
#   'geolocation/degrade_flag',
#   'selected_l2a_algorithm',
#   'rx_processing/rg_eg_sigma_error_a1',
#   'geolocation/elev_lowestmode',
#   'geolocation/delta_time',
#   'rx_processing/rg_eg_amplitude_error_a3',
#   'selected_rg_algorithm',
#   'ancillary/signal_search_buff',
#   'rx_processing/rg_eg_chisq_a5',
#   'rx_processing/rg_eg_amplitude_a5',
#   'rx_processing/rg_eg_sigma_a6',
#   'geolocation/elevation_bin0',
#   'rx_processing/rg_eg_sigma_error_a6']}

# %% [markdown]
# geojson to json helper block

# %%
import json
import geopandas as gpd

# Input GeoJSON file path
geojson_path = "https://raw.githubusercontent.com/SERVIR/GEDI_Earthhub_ARSET_Training/main/AOIs/prescribed_burn_aoi.geojson"

# Load GeoJSON as a GeoDataFrame
gdf = gpd.read_file(geojson_path)

# Convert GeoDataFrame to dictionary
geojson_dict = json.loads(gdf.to_json())

# Output plain JSON file
json_path = "prescribed_burn_plain.json"
with open(json_path, "w") as f:
    json.dump(geojson_dict, f, indent=2)

print(f"✅ Converted GeoJSON to JSON: {json_path}")
# Out:
# ✅ Converted GeoJSON to JSON: prescribed_burn_plain.json

# %%
import json

def update_json_metadata(file_path, new_metadata):
    """Updates metadata in a JSON file.

    Args:
        file_path: Path to the JSON file.
        new_metadata: A dictionary containing the new metadata to add/update.
    """
    try:
        # 1. Read the JSON file
        with open(file_path, 'r') as f:
            json_data = json.load(f)

        # 2. Modify the metadata
        for key, value in new_metadata.items():
            json_data[key] = value

        # 3. Convert back to JSON
        updated_json = json.dumps(json_data, indent=4) # Indent for readability

        # 4. Write the updated JSON to the file
        with open(file_path, 'w') as f:
            f.write(updated_json)

        print(f"Metadata updated successfully in {file_path}")

    except FileNotFoundError:
        print(f"Error: File not found at {file_path}")
    except json.JSONDecodeError:
        print(f"Error: Invalid JSON format in {file_path}")
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage:
file_path = "/content/prescribed_burn_plain.json"
new_metadata = field
update_json_metadata(file_path, new_metadata)
# Out:
# Metadata updated successfully in /content/prescribed_burn_plain.json

# %%
#'/content/GEDI_Datasets.json'

with open('/content/prescribed_burn_plain.json', 'r') as fp:
    gedi_var = json.load(fp)

L2B = gedi_var['GEDI_L2B']
L2B[0:25]
# Out:
# ['rx_processing/rg_eg_flag_a4',
#  'rx_processing/rg_eg_gamma_error_a5',
#  'rx_processing/rg_eg_gamma_error_a1',
#  'rx_processing/rg_error_a3',
#  'rx_processing/rg_eg_amplitude_a2',
#  'geolocation/local_beam_elevation',
#  'ancillary/rg_eg_constraint_center_buffer',
#  'rx_processing/rx_energy_a6',
#  'ancillary/tx_noise_stddev_multiplier',
#  'pgap_theta_z',
#  'rx_processing/rg_eg_center_error_a5',
#  'rx_processing/pgap_theta_a4',
#  'land_cover_data/modis_nonvegetated',
#  'geolocation/longitude_bin0_error',
#  'rx_processing/rg_error_a1',
#  'geolocation/elev_highestreturn',
#  'land_cover_data/landsat_water_persistence',
#  'land_cover_data/leaf_on_doy',
#  'rx_processing/algorithmrun_flag_a5',
#  'geolocation/lon_lowestmode',
#  'rx_processing/rx_energy_a4',
#  'geolocation/digital_elevation_model',
#  'rhov',
#  'rx_processing/rg_a5',
#  'rx_processing/rg_error_a2']

# %%
subset_L2B = ['geolocation/lat_lowestmode', 'geolocation/lon_lowestmode', 'geolocation/degrade_flag', 'geolocation/digital_elevation_model', 'geolocation/elev_lowestmode', 'lat_highestreturn', 'geolocation/lon_highestreturn', 'geolocation/elev_highestreturn', 'l2b_quality_flag', 'rh100', 'pai', 'pai_z', 'pavd_z']
# subset_L2B = ['geolocation/lat_lowestmode', 'geolocation/lon_lowestmode', 'rh100']

datasets_p = []
for s in subset_L2B:
    my_var = [v for v in L2B if v.endswith(f'{s}')]
    if len(my_var) == 1:
        datasets_p.append(my_var[0])

    elif len(my_var) > 1:
        my_var = [v for v in my_var if v.startswith(f'{s}')]

        for l in my_var:
            if l not in datasets_p:
                datasets_p.append(l)

datasets_p
# Out:
# ['geolocation/lat_lowestmode',
#  'geolocation/lon_lowestmode',
#  'geolocation/degrade_flag',
#  'geolocation/digital_elevation_model',
#  'geolocation/elev_lowestmode',
#  'geolocation/lat_highestreturn',
#  'geolocation/lon_highestreturn',
#  'geolocation/elev_highestreturn',
#  'l2b_quality_flag',
#  'rh100',
#  'pai',
#  'pai_z',
#  'pavd_z']

# %% [markdown]
# Select the subset of your desired beams. For instance, you can only select Full Power beams ('BEAM0101', 'BEAM0110', 'BEAM1000', 'BEAM1011').

# %%
beams = ['BEAM0101', 'BEAM0110', 'BEAM1000', 'BEAM1011']  #['BEAM0000', 'BEAM0001', 'BEAM0010', 'BEAM0011', 'BEAM0101', 'BEAM0110', 'BEAM1000', 'BEAM1011']

# %%
subset = []
for b in beams:
    beam_subset = [f'/{b}/{layer}' for layer in datasets_p]
    [subset.append(i) for i in beam_subset]
subset
# Out:
# ['/BEAM0101/geolocation/lat_lowestmode',
#  '/BEAM0101/geolocation/lon_lowestmode',
#  '/BEAM0101/geolocation/degrade_flag',
#  '/BEAM0101/geolocation/digital_elevation_model',
#  '/BEAM0101/geolocation/elev_lowestmode',
#  '/BEAM0101/geolocation/lat_highestreturn',
#  '/BEAM0101/geolocation/lon_highestreturn',
#  '/BEAM0101/geolocation/elev_highestreturn',
#  '/BEAM0101/l2b_quality_flag',
#  '/BEAM0101/rh100',
#  '/BEAM0101/pai',
#  '/BEAM0101/pai_z',
#  '/BEAM0101/pavd_z',
#  '/BEAM0110/geolocation/lat_lowestmode',
#  '/BEAM0110/geolocation/lon_lowestmode',
#  '/BEAM0110/geolocation/degrade_flag',
#  '/BEAM0110/geolocation/digital_elevation_model',
#  '/BEAM0110/geolocation/elev_lowestmode',
#  '/BEAM0110/geolocation/lat_highestreturn',
#  '/BEAM0110/geolocation/lon_highestreturn',
#  '/BEAM0110/geolocation/elev_highestreturn',
#  '/BEAM0110/l2b_quality_flag',
#  '/BEAM0110/rh100',
#  '/BEAM0110/pai',
#  '/BEAM0110/pai_z',
#  '/BEAM0110/pavd_z',
#  '/BEAM1000/geolocation/lat_lowestmode',
#  '/BEAM1000/geolocation/lon_lowestmode',
#  '/BEAM1000/geolocation/degrade_flag',
#  '/BEAM1000/geolocation/digital_elevation_model',
#  '/BEAM1000/geolocation/elev_lowestmode',
#  '/BEAM1000/geolocation/lat_highestreturn',
#  '/BEAM1000/geolocation/lon_highestreturn',
#  '/BEAM1000/geolocation/elev_highestreturn',
#  '/BEAM1000/l2b_quality_flag',
#  '/BEAM1000/rh100',
#  '/BEAM1000/pai',
#  '/BEAM1000/pai_z',
#  '/BEAM1000/pavd_z',
#  '/BEAM1011/geolocation/lat_lowestmode',
#  '/BEAM1011/geolocation/lon_lowestmode',
#  '/BEAM1011/geolocation/degrade_flag',
#  '/BEAM1011/geolocation/digital_elevation_model',
#  '/BEAM1011/geolocation/elev_lowestmode',
#  '/BEAM1011/geolocation/lat_highestreturn',
#  '/BEAM1011/geolocation/lon_highestreturn',
#  '/BEAM1011/geolocation/elev_highestreturn',
#  '/BEAM1011/l2b_quality_flag',
#  '/BEAM1011/rh100',
#  '/BEAM1011/pai',
#  '/BEAM1011/pai_z',
#  '/BEAM1011/pavd_z']

# %% [markdown]
# ### Spatial Subset

# %% [markdown]
# Both `spatial` and` shape` are the query parameters used for spatial subsetting using bounding box and shapefile/GeoJSON respectively. For the Bounding box, the Harmony `Bbox` class accepts spatial coordinates as decimal degrees in the order of west, south, east, and north coordinates (e.g.(-119.205104, 36.012018, -117.907297, 37.054834)). For the spatial subset using a region of interest, the path to a GeoJSON file (.json or .geojson), an ESRI Shapefile (.zip or .shz), or a kml file (.kml) as `shape` param are acceptable inputs.

# %%
## path to the GeoJSON
#roi = BBox(-119.205104, 36.012018, -117.907297, 37.054834)

roi = BBox(-86.68321, 30.9953, -86.62707, 30.9953)

# %% [markdown]
# ### Temporal Subset

# %% [markdown]
# For temporal subsetting, the data temporal start and end ranges are used as a datetime object. Below, the start and end dates for the query are selected.

# %%
temporal_range = {'start': datetime(2022, 4, 1),
                  'stop': datetime(2022, 4, 20)}

# %% [markdown]
# Finally, submit the Harmony request and retrieve the request ID.

# %%
request = Request(
    collection = Collection(id=concept_id),
    spatial = roi,    # for bbox
    # shape = roi,   # for the GeoJSON
    temporal = temporal_range,
    variables = subset
)

# %% [markdown]
# You can check the validity of the request before submitting a Harmony Request.

# %%
request.is_valid()
# Out:
# True

# %% [markdown]
# Finally, submit the request and retrieve list of the processed data URLs once processing is complete. You may optionally show the progress bar below.

# %%
task = harmony_client.submit(request)
print(f'Harmony request ID: {task}')

print(f'Processing your Harmony request:')
task_json = harmony_client.result_json(task, show_progress=True)
# Out:
# Harmony request ID: 43390290-b0df-4c80-8df9-2c76457e7c95
# Processing your Harmony request:
#  [ Processing: 100% ] |###################################################| [|]

# %% [markdown]
# Next, download the subset of data.

# %%
results = harmony_client.download_all(task, directory='content', overwrite=True)

# %%
file_names = [f.result() for f in results]
# Out:
# content/101258389_GEDI02_B_2022103132503_O18884_02_T10864_02_003_01_V002_subsetted.h5

# %% [markdown]
# Function is defined to create a DataFrame from our HDF5 Harmony subset file. Next, `GeoDataFrame` is created for all the downloaded subset file.

# %%
def h5_to_dataframe(ds, beams, vars):
    """
    This function takes Harmony subset of GEDI hdf5 and returns a DataFrame.
    """
    #read the dataset
    gedi_ds = h5py.File(ds,'r')
    # see what is the data product
    product = gedi_ds['METADATA']['DatasetIdentification'].attrs['shortName']
    fileName = gedi_ds['METADATA']['DatasetIdentification'].attrs['fileName']
    date = datetime.strptime(fileName.rsplit('_')[2], '%Y%j%H%M%S').strftime('%Y-%m-%d %H:%M:%S')
    # Create an empty DataFrame for this beam
    df_beam = pd.DataFrame(columns=vars)

    for b in beams:
        data_dic = {}
        for v in vars:
            # print(b,v)
            value = gedi_ds[f'{b}/{v}'][()]
            data_dic[v] = value.tolist()

        df_beam = pd.concat([df_beam, pd.DataFrame(data_dic)],join="inner")

        # add product, beam, file name, and date columns
        df_beam.insert(0, 'product', product)
        df_beam.insert(1, 'Beam', b)
        df_beam.insert(2, 'fileName' , fileName)
        df_beam.insert(3, 'date', date)

    return(df_beam.reset_index(drop=True))

# %%
l2b_df = pd.DataFrame()

for file in file_names:
    print(file)
    gedi_subset = h5_to_dataframe(file, beams, datasets_p)
    l2b_df = gp.GeoDataFrame(pd.concat([l2b_df, gedi_subset]))
    del gedi_subset

# Reset the indeces
l2b_df = l2b_df.reset_index(drop=True)
l2b_df = l2b_df.rename(columns={'geolocation/lat_lowestmode': 'lat', 'geolocation/lon_lowestmode': 'lon'})
 # Take the lat/lon from DataFrame and convert each lat/lon to a shapely point and convert to a GeoDataFrame
l2b_df = gp.GeoDataFrame(l2b_df, geometry=l2b_df.apply(lambda row: Point(row.lon, row.lat), axis=1))
# Out:
# content/101258389_GEDI02_B_2022103132503_O18884_02_T10864_02_003_01_V002_subsetted.h5
# <ipython-input-22-4a505d0ee717>:21: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_beam = pd.concat([df_beam, pd.DataFrame(data_dic)],join="inner")

# %%
l2b_df.head()
# Out:
#     product      Beam                                           fileName  \
# 0  GEDI_L2B  BEAM1011  GEDI02_B_2022103132503_O18884_02_T10864_02_003...
# 1  GEDI_L2B  BEAM1011  GEDI02_B_2022103132503_O18884_02_T10864_02_003...
# 2  GEDI_L2B  BEAM1011  GEDI02_B_2022103132503_O18884_02_T10864_02_003...
# 3  GEDI_L2B  BEAM1011  GEDI02_B_2022103132503_O18884_02_T10864_02_003...
# 4  GEDI_L2B  BEAM1011  GEDI02_B_2022103132503_O18884_02_T10864_02_003...
#
#                   date        lat        lon geolocation/degrade_flag  \
# 0  2022-04-13 13:25:03  30.907927 -86.682993                        0
# 1  2022-04-13 13:25:03  30.908298 -86.682579                        0
# 2  2022-04-13 13:25:03  30.908667 -86.682165                        0
# 3  2022-04-13 13:25:03  30.909037 -86.681750                        0
# 4  2022-04-13 13:25:03  30.909407 -86.681336                        0
#
#    geolocation/digital_elevation_model  geolocation/elev_lowestmode  \
# 0                            26.355474                    59.715824
# 1                            28.530102                    60.324383
# 2                            28.530102                    60.202522
# 3                            28.677153                    60.551300
# 4                            28.677153                    60.544659
#
#    geolocation/lat_highestreturn  geolocation/lon_highestreturn  \
# 0                      30.907927                     -86.682993
# 1                      30.908298                     -86.682579
# 2                      30.908667                     -86.682165
# 3                      30.909037                     -86.681750
# 4                      30.909407                     -86.681336
#
#    geolocation/elev_highestreturn l2b_quality_flag rh100     pai  \
# 0                       59.715824                0     0 -9999.0
# 1                       60.324383                0     0 -9999.0
# 2                       60.202522                0     0 -9999.0
# 3                       60.551300                0     0 -9999.0
# 4                       60.544659                0     0 -9999.0
#
#                                                pai_z  \
# 0  [-9999.0, -9999.0, -9999.0, -9999.0, -9999.0, ...
# 1  [-9999.0, -9999.0, -9999.0, -9999.0, -9999.0, ...
# 2  [-9999.0, -9999.0, -9999.0, -9999.0, -9999.0, ...
# 3  [-9999.0, -9999.0, -9999.0, -9999.0, -9999.0, ...
# 4  [-9999.0, -9999.0, -9999.0, -9999.0, -9999.0, ...
#
#                                               pavd_z  \
# 0  [-9999.0, -9999.0, -9999.0, -9999.0, -9999.0, ...
# 1  [-9999.0, -9999.0, -9999.0, -9999.0, -9999.0, ...
# 2  [-9999.0, -9999.0, -9999.0, -9999.0, -9999.0, ...
# 3  [-9999.0, -9999.0, -9999.0, -9999.0, -9999.0, ...
# 4  [-9999.0, -9999.0, -9999.0, -9999.0, -9999.0, ...
#
#                      geometry
# 0  POINT (-86.68299 30.90793)
# 1   POINT (-86.68258 30.9083)
# 2  POINT (-86.68216 30.90867)
# 3  POINT (-86.68175 30.90904)
# 4  POINT (-86.68134 30.90941)

# %%
l2b_df.hvplot(cmap='viridis', clim=(0,l2b_df['pai'].max()), color='pai', size=10, frame_width=900, geo=True, tiles='ESRI')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Longitude,Latitude]   (pai)

# %% [markdown]
# ## Contact Info:
#
# Email: LPDAAC@usgs.gov
# Voice: +1-866-573-3222
# Organization: Land Processes Distributed Active Archive Center (LP DAAC)¹
# Website: <https://lpdaac.usgs.gov/>
# Date last modified: 02-20-2024
#
# ¹Work performed under USGS contract G15PD00467 for NASA contract NNG14HH33I.
